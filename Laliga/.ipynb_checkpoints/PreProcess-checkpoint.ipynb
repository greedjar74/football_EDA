# %% [markdown]
# # 데이터 병합

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # player데이터 병합

# %%
player_def_path = './LL_Player_Def/'
player_off_path = './LL_Player_Off/'
player_pass_path = './LL_Player_Pass/'
player_summary_path = './LL_Player_Summary/'

# %%
player_def_path_list = os.listdir(player_def_path)
player_off_path_list = os.listdir(player_off_path)
player_pass_path_list = os.listdir(player_pass_path)
player_summary_path_list = os.listdir(player_summary_path)

# %%
print(player_def_path_list)
print(player_off_path_list)
print(player_pass_path_list)
print(player_summary_path_list)
# Out:
# ['19_20_LL_Player_Stats_def.csv', '18_19_LL_Player_Stats_def.csv', '20_21_LL_Player_Stats_def.csv', '22_23_LL_Player_Stats_def.csv', '21_22_LL_Player_Stats_def.csv']
# ['18_19_LL_Player_Stats_off.csv', '19_20_LL_Player_Stats_off.csv', '21_22_LL_Player_Stats_off.csv', '22_23_LL_Player_Stats_off.csv', '20_21_LL_Player_Stats_off.csv']
# ['22_23_LL_Player_Stats_Pass.csv', '18_19_LL_Player_Stats_Pass.csv', '20_21_LL_Player_Stats_Pass.csv', '21_22_LL_Player_Stats_Pass.csv', '19_20_LL_Player_Stats_Pass.csv']
# ['18_19_LL_Player_Stats.csv', '21_22_LL_Player_Stats.csv', '19_20_LL_Player_Stats.csv', '22_23_LL_Player_Stats.csv', '20_21_LL_Player_Stats.csv']

# %%
player_def_path_list.sort()
player_off_path_list.sort()
player_pass_path_list.sort()
player_summary_path_list.sort()

# %%
player_summary_path_list
# Out:
# ['18_19_LL_Player_Stats.csv',
#  '19_20_LL_Player_Stats.csv',
#  '20_21_LL_Player_Stats.csv',
#  '21_22_LL_Player_Stats.csv',
#  '22_23_LL_Player_Stats.csv']

# %%
print(player_def_data[0].shape)
print(player_off_data[0].shape)
print(player_pass_data[0].shape)
print(player_summary_data[0].shape)
# Out:
# (296, 9)
# (296, 9)
# (296, 6)
# (296, 15)

# %%
player_summary_data = []
for path in player_summary_path_list:
    player_summary_data.append(pd.read_csv(player_summary_path + path))
    
player_def_data = []
for path in player_def_path_list:
    player_def_data.append(pd.read_csv(player_def_path + path))

player_off_data = []
for path in player_off_path_list:
    player_off_data.append(pd.read_csv(player_off_path + path))

player_pass_data = []
for path in player_pass_path_list:
    player_pass_data.append(pd.read_csv(player_pass_path + path))

# %%
for data in player_summary_data:
    data.drop('Unnamed: 0', axis=1, inplace=True)
    
for data in player_def_data:
    data.drop('Unnamed: 0', axis=1, inplace=True)
    
for data in player_off_data:
    data.drop('Unnamed: 0', axis=1, inplace=True)
    
for data in player_pass_data:
    data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
player_merged_data_list = []

for i in range(5):
    tmp1 = pd.merge(player_summary_data[i], player_def_data[i], on='Name', how='inner')
    tmp2 = pd.merge(tmp1, player_off_data[i], on='Name', how='inner')
    tmp3 = pd.merge(tmp2, player_pass_data[i], on='Name', how='inner')
    
    player_merged_data_list.append(tmp3)
# Out:
#             Name         Team  Age     Position   Apps  Mins Goals Assists  \
# 0   Lionel Messi    Barcelona   36    AM(CR),FW  29(5)  2710    36      13
# 1    Luis Suárez    Barcelona   37   AM(CLR),FW  31(2)  2830    21       6
# 2     Iago Aspas   Celta Vigo   36    AM(CR),FW  26(1)  2262    20       6
# 3    Dani Parejo     Valencia   35         M(C)  35(1)  3063     9       7
# 4  Karim Benzema  Real Madrid   36           FW  35(1)  2964    21       6
#
#   Yellow Red  SpG    PS Aerialswon MotM  Rating
# 0      3   -    5  81.3        0.2   17    8.48
# 1      5   -  3.4  75.3        0.7    5    7.57
# 2      5   -  2.6  82.0        0.9    6    7.51
# 3      6   1  1.2  85.8        0.9    9    7.40
# 4      1   -  2.9  82.6        1.2    7    7.38
#             Name Tackles Inter Fouls Offsides Clear  Drb Blocks OwnG
# 0   Lionel Messi     0.4   0.1   0.6        -     -  0.5      -    -
# 1    Luis Suárez     0.5   0.2   0.9        -   0.7  0.2    0.1    -
# 2     Iago Aspas     0.6   0.6   0.6        -   0.2  0.6      -    -
# 3    Dani Parejo       2   1.3   0.8        -   0.6  1.6    0.2    -
# 4  Karim Benzema     0.7   0.2   0.6        -   0.7  0.4      -    -
#             Name Goals Assists  SpG  Drb Fouled  Off Disp UnsTch
# 0   Lionel Messi    36      13    5  3.9    1.9  0.5  2.3    2.3
# 1    Luis Suárez    21       6  3.4  1.1    1.7  0.8  1.6    1.6
# 2     Iago Aspas    20       6  2.6  0.7    1.6  0.3  1.3    1.3
# 3    Dani Parejo     9       7  1.2    1    1.5    -  0.6    0.6
# 4  Karim Benzema    21       6  2.9  1.3    0.6    1  1.3    1.3
#             Name  AvgP   PSp Crosses  LonB ThrB
# 0   Lionel Messi  53.8  81.3     0.4   3.4  0.9
# 1    Luis Suárez  29.0  75.3     0.2   1.5  0.1
# 2     Iago Aspas  32.1  82.0     0.2   1.4  0.2
# 3    Dani Parejo  61.5  85.8     1.9   5.6  0.1
# 4  Karim Benzema  32.9  82.6     0.1   1.1  0.1
#
#             Name           Team  Age     Position   Apps  Mins Goals Assists  \
# 0   Lionel Messi      Barcelona   36    AM(CR),FW  32(1)  2881    25      21
# 1       Casemiro    Real Madrid   32     D(C),DMC     35  3091     4       3
# 2  Karim Benzema    Real Madrid   36           FW  36(1)  3155    21       8
# 3    Luis Suárez      Barcelona   37   AM(CLR),FW  22(6)  2002    16       8
# 4   Mikel Merino  Real Sociedad   27         M(C)  35(1)  3144     5       1
#
#   Yellow Red  SpG    PS  Aerialswon MotM  Rating
# 0      4   -  4.8  82.6         0.3   22    8.71
# 1     12   -  1.3  84.1         2.9    3    7.47
# 2      -   -  3.4  86.2         0.8   10    7.44
# 3      4   -  2.8  75.5         0.4    3    7.33
# 4      9   -  1.2  75.8         5.1    5    7.31
#             Name Tackles Inter Fouls Offsides Clear  Drb Blocks OwnG
# 4             Rodrygo  Real Madrid   23   AM(CLR),FW  25(9)  2382     9
#
#   Assists Yellow Red  SpG    PS Aerialswon MotM  Rating
# 0      16      2   -  2.9  82.4        0.7   13    7.69
# 1       3      1   -  4.5  87.0        0.6    6    7.53
# 2       7      2   1    4  78.1        1.5    7    7.49
# 3       9     10   1  2.3  80.6        0.1    4    7.35
# 4       8      4   -  2.9  89.6        0.4    4    7.26
#                  Name Tackles Inter Fouls Offsides Clear  Drb Blocks OwnG
# 0   Antoine Griezmann     1.3   0.6   0.6        -   0.8  1.2    0.1    -
# 1       Karim Benzema     0.4   0.1   0.4        -   0.2  0.4      -    -
# 2  Robert Lewandowski     0.5   0.1   1.1      0.1   0.4  0.2      -    -
# 3     Vinícius Júnior     0.9   0.2   1.4        -     -  0.8      -    -
# 4             Rodrygo     0.5   0.2   0.5        -   0.1  0.6      -    -
#                  Name Goals Assists  SpG  Drb Fouled  Off Disp UnsTch
# 0   Antoine Griezmann    15      16  2.9  1.2    1.1  0.3  0.9    0.9
# 1       Karim Benzema    19       3  4.5  0.8    0.3  0.9  1.2    1.2
# 2  Robert Lewandowski    23       7    4  0.9    1.4  0.6  1.5    1.5
# 3     Vinícius Júnior    10       9  2.3  3.4    3.7  0.7  1.8    1.8
# 4             Rodrygo     9       8  2.9  2.4    1.4  0.3  0.9    0.9
#                  Name  AvgP   PSp Crosses LonB ThrB
# 0   Antoine Griezmann  38.3  82.4     0.8  1.8  0.2
# 1       Karim Benzema  44.0  87.0       -  0.6  0.3
# 2  Robert Lewandowski  22.4  78.1     0.2  0.7  0.2
# 3     Vinícius Júnior  32.1  80.6     0.2  0.9  0.1
# 4             Rodrygo  29.7  89.6     0.2  0.5    -

# %%
for player_merged_data in player_merged_data_list:
    player_merged_data.drop(['Goals_y', 'Assists_y', 'SpG_y'], axis=1, inplace=True)

# %%
for player_ merged_data in player_merged_data_list:
    player_merged_data.columns = ['Name', 'Team', 'Age', 'Position', 'Apps', 'Mins', 'Goals',
       'Assists', 'Yellow', 'Red', 'SpG', 'PS', 'Aerialswon', 'MotM',
       'Rating', 'Tackles', 'Inter', 'Fouls', 'Offsides', 'Clear', 'Drb_def',
       'Blocks', 'OwnG', 'Drb_off', 'Fouled', 'Off', 'Disp', 'UnsTch', 'AvgP',
       'PSp', 'Crosses', 'LonB', 'ThrB']
# Out:
#   Cell In[18], line 1
#     forplayer_ merged_data in player_merged_data_list:
#                ^
# SyntaxError: invalid syntax

# %%
player_merged_data_list[0].to_csv('18_19_LL_Player.csv')
player_merged_data_list[1].to_csv('19_20_LL_Player.csv')
player_merged_data_list[2].to_csv('20_21_LL_Player.csv')
player_merged_data_list[3].to_csv('21_22_LL_Player.csv')
player_merged_data_list[4].to_csv('22_23_LL_Player.csv')

# %% [markdown]
# # team 데이터 병합

# %%
team_def_path = './BL_Team_Def/'
team_off_path = './BL_Team_Off/'
team_table_path = './BL_Team_Table/'
team_summary_path = './BL_Team_Summary/'

# %%
team_def_path_list = os.listdir(team_def_path)
team_off_path_list = os.listdir(team_off_path)
team_table_path_list = os.listdir(team_table_path)
team_summary_path_list = os.listdir(team_summary_path)

# %%
team_def_path_list.sort()
team_off_path_list.sort()
team_table_path_list.sort()
team_summary_path_list.sort()

# %%
team_def_path_list
# Out:
# ['18_19_BL_Team_Stats_defensive.csv',
#  '19_20_BL_Team_Stats_defensive.csv',
#  '20_21_BL_Team_Stats_defensive.csv',
#  '21_22_BL_Team_Stats_defensive.csv',
#  '22_23_BL_Team_Stats_defensive.csv']

# %%
team_summary_data = []
for path in team_summary_path_list:
    team_summary_data.append(pd.read_csv(team_summary_path + path))
    
team_def_data = []
for path in team_def_path_list:
    team_def_data.append(pd.read_csv(team_def_path + path))

team_off_data = []
for path in team_off_path_list:
    team_off_data.append(pd.read_csv(team_off_path + path))

team_table_data = []
for path in team_table_path_list:
    team_table_data.append(pd.read_csv(team_table_path + path))

# %%
for data in team_summary_data:
    data.drop('Unnamed: 0', axis=1, inplace=True)
    
for data in team_def_data:
    data.drop('Unnamed: 0', axis=1, inplace=True)
    
for data in team_off_data:
    data.drop('Unnamed: 0', axis=1, inplace=True)
    
for data in team_table_data:
    data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
team_merged_data_list = []

for i in range(5):
    tmp1 = pd.merge(team_summary_data[i], team_def_data[i], on='Team', how='inner')
    print(tmp1.shape)
    tmp2 = pd.merge(tmp1, team_off_data[i], on='Team', how='inner')
    print(tmp2.shape)
    tmp3 = pd.merge(tmp2, team_table_data[i], on='Team', how='inner')
    print(tmp3.shape)
    
    team_merged_data_list.append(tmp3)
# Out:
# (18, 14)
# (18, 18)
# (17, 26)
# (18, 14)
# (18, 18)
# (17, 26)
# (18, 14)
# (18, 18)
# (17, 26)
# (18, 14)
# (18, 18)
# (17, 26)
# (18, 14)
# (18, 18)
# (17, 26)

# %%
for data in team_def_data:
    team_li = data['Team'].unique().tolist()
    for i in range(len(team_li)):
        if team_li[i] == 'Borussia M':
            team_li[i] = 'Borussia M.Gladbach'
            
    tmp = pd.DataFrame(team_li, columns=['Team'])
    data['Team'] = tmp

for data in team_off_data:
    team_li = data['Team'].unique().tolist()
    for i in range(len(team_li)):
        if team_li[i] == 'Borussia M':
            team_li[i] = 'Borussia M.Gladbach'
            
    tmp = pd.DataFrame(team_li, columns=['Team'])
    data['Team'] = tmp

for data in team_pass_data:
    team_li = data['Team'].unique().tolist()
    for i in range(len(team_li)):
        if team_li[i] == 'Borussia M':
            team_li[i] = 'Borussia M.Gladbach'
            
    tmp = pd.DataFrame(team_li, columns=['Team'])
    data['Team'] = tmp

# %%
team_summary_data[0]
# Out:
#                    Team  Goals  Shotspg  Yellow  Red  Possession  Pass  \
# 0         Bayern Munich     88     18.7      40    2        62.2  87.5
# 1            RB Leipzig     63     14.6      61    1        49.5  75.3
# 2     Borussia Dortmund     81     13.2      40    3        56.8  86.0
# 3      Bayer Leverkusen     69     15.2      50    1        57.7  84.4
# 4            Hoffenheim     70     18.0      65    2        52.8  82.0
# 5   Eintracht Frankfurt     60     12.4      56    3        47.6  73.1
# 6             Wolfsburg     62     12.5      62    0        52.5  78.6
# 7            Borussia M     55     13.5      43    0        52.3  84.3
# 8         Werder Bremen     58     13.9      58    3        51.2  80.0
# 9         Hertha Berlin     49     11.9      61    5        48.6  78.4
# 10             Mainz 05     46     14.6      56    0        46.9  77.1
# 11  Fortuna Duesseldorf     49     12.3      67    1        44.4  77.4
# 12           Schalke 04     37     12.2      71    5        46.9  76.3
# 13             Augsburg     51     13.4      55    1        46.8  74.5
# 14             Freiburg     46     12.5      51    3        45.4  78.2
# 15        VfB Stuttgart     32     12.0      62    5        46.8  75.7
# 16          Hannover 96     31     11.3      59    4        47.4  76.8
# 17            Nuernberg     26     10.6      57    4        44.1  76.0
#
#     AerialsWon  Rating
# 0         15.7    7.03
# 1         22.4    6.96
# 2         14.0    6.93
# 3         16.6    6.88
# 4         15.9    6.87
# 5         24.6    6.83
# 6         18.9    6.81
# 7         13.2    6.76
# 8         18.1    6.75
# 9         20.9    6.74
# 10        19.6    6.70
# 11        18.7    6.67
# 12        18.0    6.65
# 13        20.0    6.65
# 14        16.9    6.64
# 15        21.9    6.57
# 16        18.6    6.57
# 17        19.0    6.49

# %%
team_merged_data_list = []

for i in range(5):
    tmp1 = pd.merge(team_table_data[i], team_summary_data[i], on='Team', how='inner')
    print(tmp1.shape)
    tmp2 = pd.merge(tmp1, team_def_data[i], on='Team', how='inner')
    print(tmp2.shape)
    tmp3 = pd.merge(tmp2, team_off_data[i], on='Team', how='inner')
    print(tmp3.shape)
    
    team_merged_data_list.append(tmp3)
# Out:
# (17, 17)
# (17, 22)
# (17, 26)
# (17, 17)
# (17, 22)
# (17, 26)
# (17, 17)
# (17, 22)
# (17, 26)
# (17, 17)
# (17, 22)
# (17, 26)
# (17, 17)
# (17, 22)
# (17, 26)

# %%
team_merged_data_list[0].columns
# Out:
# Index(['Team', 'P', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Goals', 'Shotspg',
#        'Yellow', 'Red', 'Possession', 'Pass', 'AerialsWon', 'Rating',
#        'def_Shotspg', 'def_Tacklespg', 'def_Interceptionspg', 'def_Foulspg',
#        'def_Offsidespg', 'of_Shotspg', 'of_ShotsOTpg', 'of_Dribblespg',
#        'of_Fouledpg'],
#       dtype='object')

# %%
team_merged_data_list[0].to_csv('18_19_BL_Team.csv')
team_merged_data_list[1].to_csv('19_20_BL_Team.csv')
team_merged_data_list[2].to_csv('20_21_BL_Team.csv')
team_merged_data_list[3].to_csv('21_22_BL_Team.csv')
team_merged_data_list[4].to_csv('22_23_BL_Team.csv')
