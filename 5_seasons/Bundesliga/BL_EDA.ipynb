# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # 데이터 가져오기

# %% [markdown]
# ## BL player 데이터

# %%
player_path = './BL_5years_player/'
player_path_list = os.listdir(player_path)
player_path_list.sort()
player_path_list
# Out:
# ['18_19_BL_Player.csv',
#  '19_20_BL_Player.csv',
#  '20_21_BL_Player.csv',
#  '21_22_BL_Player.csv',
#  '22_23_BL_Player.csv']

# %%
player_data_list = []

for path in player_path_list:
    player_data_list.append(pd.read_csv(player_path + path))

# %%
for data in player_data_list:
    data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
player_data_list[3]
# Out:
#                    Name               Team  Age         Position    Apps  \
# 0    Robert Lewandowski             Bayern   35               FW      34
# 1    Christopher Nkunku                RBL   26        M(CLR),FW   31(3)
# 2        Joshua Kimmich             Bayern   29   D(CR),DMC,M(R)      28
# 3        Erling Haaland  Borussia Dortmund   23               FW   21(3)
# 4         Patrik Schick         Leverkusen   28         AM(R),FW   26(1)
# ..                  ...                ...  ...              ...     ...
# 287      Florian Krüger  Arminia Bielefeld   25       AM(CLR),FW  12(15)
# 288         Jan Morávek           Augsburg   34             M(C)   5(12)
# 289      Dickson Abiama    Greuther Fuerth   25               FW   5(19)
# 290        Julian Green    Greuther Fuerth   28         M(CL),FW  12(12)
# 291    Nathan De Medina  Arminia Bielefeld   26            D(CR)   7(12)
#
#      Mins Goals Assists Yellow Red  ... Drb_off  Fouled  Off Disp  UnsTch  \
# 0    2952    35       3      2   -  ...     1.4     1.1  0.6  1.6     1.6
# 1    2735    20      13      2   -  ...     1.9     1.8  0.4  1.5     1.5
# 2    2478     3      11      4   -  ...     0.8     1.6    -  0.6     0.6
# 3    1915    22       7      3   -  ...     0.5     0.6  0.6  0.7     0.7
# 4    2094    24       3      -   -  ...     0.6     0.8  0.2  0.8     0.8
# ..    ...   ...     ...    ...  ..  ...     ...     ...  ...  ...     ...
# 287  1112     1       2      -   -  ...     0.3     0.3  0.1  0.3     0.3
# 288   466     -       -      1   -  ...     0.3     0.1    -  0.4     0.4
# 289   715     -       1      3   -  ...     0.3     0.5  0.6  0.4     0.4
# 290  1052     -       -      2   -  ...     0.3     1.6    -  0.2     0.2
# 291   768     -       -      2   -  ...       -     0.5    -  0.3     0.3
#
#      AvgP   PSp Crosses LonB ThrB
# 0    21.6  77.4     0.1  0.4  0.1
# 1    28.2  81.8     0.6  0.6  0.2
# 2    84.2  88.0     2.4    5  0.3
# 3    19.2  71.3       -    -  0.1
# 4    15.1  68.9       -  0.2    -
# ..    ...   ...     ...  ...  ...
# 287   9.9  70.1     0.1  0.2    -
# 288  10.9  70.4       -  0.6    -
# 289   5.5  63.6       -    -  0.1
# 290  15.5  83.4     0.4  0.7    -
# 291  13.3  73.0     0.1  0.5    -
#
# [292 rows x 33 columns]

# %% [markdown]
# ## BL team 데이터

# %%
team_path = './BL_5years_Team/'
team_path_list = os.listdir(team_path)
team_path_list.sort()
team_path_list.pop(0)
team_path_list
# Out:
# ['18_19_BL_Team.csv',
#  '19_20_BL_Team.csv',
#  '20_21_BL_Team.csv',
#  '21_22_BL_Team.csv',
#  '22_23_BL_Team.csv']

# %%
team_data_list = []

for path in team_path_list:
    team_data_list.append(pd.read_csv(team_path + path))

# %%
for data in team_data_list:
    data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
team_data_list[3]
# Out:
#                    Team   P   W   D   L  GF  GA  GD  Pts  Goals  ...  Rating  \
# 0         Bayern Munich  34  24   5   5  97  37  60   77     97  ...    6.98
# 1     Borussia Dortmund  34  22   3   9  85  52  33   69     85  ...    6.77
# 2      Bayer Leverkusen  34  19   7   8  80  47  33   64     80  ...    6.77
# 3            RB Leipzig  34  17   7  10  72  37  35   58     72  ...    6.77
# 4          Union Berlin  34  16   9   9  50  44   6   57     50  ...    6.61
# 5              Freiburg  34  15  10   9  58  46  12   55     58  ...    6.68
# 6               FC Koln  34  14  10  10  52  49   3   52     52  ...    6.65
# 7              Mainz 05  34  13   7  14  50  45   5   46     50  ...    6.64
# 8            Hoffenheim  34  13   7  14  58  60  -2   46     58  ...    6.59
# 9   Borussia M.Gladbach  34  12   9  13  54  61  -7   45     52  ...    6.67
# 10  Eintracht Frankfurt  34  10  12  12  45  49  -4   42     45  ...    6.60
# 11            Wolfsburg  34  12   6  16  43  54 -11   42     43  ...    6.63
# 12               Bochum  34  12   6  16  38  52 -14   42     38  ...    6.58
# 13             Augsburg  34  10   8  16  39  56 -17   38     39  ...    6.51
# 14        VfB Stuttgart  34   7  12  15  41  59 -18   33     41  ...    6.61
# 15        Hertha Berlin  34   9   6  19  37  71 -34   33     37  ...    6.48
# 16    Arminia Bielefeld  34   5  13  16  27  53 -26   28     27  ...    6.50
# 17      Greuther Fuerth  34   3   9  22  28  82 -54   18     28  ...    6.38
#
#     def_Shotspg  def_Tacklespg  def_Interceptionspg  def_Foulspg  \
# 0           9.3           16.6                 10.3          9.0
# 1          10.9           15.9                 10.2         10.6
# 2          13.4           14.2                 10.6         10.7
# 3          10.4           14.7                 10.3         10.6
# 4          11.6           15.8                 11.1         12.4
# 5          14.2           15.2                 10.4         11.5
# 6          12.6           17.6                 12.5         12.3
# 7          11.3           17.0                 12.9         14.6
# 8          12.5           14.2                  8.4         12.6
# 9          14.0           17.3                  9.8         10.6
# 10         12.7           17.5                 11.1         12.4
# 11         13.1           15.9                 11.4         12.1
# 12         14.2           17.2                 12.7         12.5
# 13         14.3           16.5                 10.7         13.2
# 14         14.8           15.6                 10.1         10.9
# 15         13.6           16.1                 11.9         12.4
# 16         15.5           16.1                 12.4         12.7
# 17         15.0           16.7                 11.0         12.9
#
#     def_Offsidespg  of_Shotspg  of_ShotsOTpg  of_Dribblespg  of_Fouledpg
# 0              2.2        19.8           7.8           14.5         10.4
# 1              2.1        13.3           5.2           10.4         11.7
# 2              1.9        13.5           5.6           11.8          9.7
# 3              1.9        12.9           5.4           10.2         12.5
# 4              1.9        12.1           4.6            7.2          9.8
# 5              1.7        13.6           4.8            6.6         11.0
# 6              2.0        13.8           4.4            7.4         13.5
# 7              1.9        13.8           4.6            7.9         11.4
# 8              2.1        13.3           4.4            7.4         10.2
# 9              2.2        14.8           5.4           10.9         13.9
# 10             1.6        13.2           4.1            8.4          8.8
# 11             2.2        12.4           4.2            9.4         12.2
# 12             2.2        12.1           4.1            6.8         11.5
# 13             2.1        10.8           3.7            7.7         10.5
# 14             1.6        13.3           4.6           11.0         12.3
# 15             2.1        10.8           3.6            8.3         12.6
# 16             1.6        10.7           3.3            8.4          9.0
# 17             2.0         9.2           3.1            7.8         12.8
#
# [18 rows x 26 columns]

# %% [markdown]
# ## Team 값 통일
# - team_data의 Team값을 기준으로 player_data의 팀 이름을 변경한다.

# %%
player_data_list[0]['Team'].unique()
# Out:
# array(['Bayern', 'Hoffenheim', 'RBL', 'Eintracht Frankfurt',
#        'Borussia Dortmund', 'Borussia M.Gladbach', 'Leverkusen',
#        'Schalke', 'Hertha Berlin', 'Wolfsburg', 'Werder Bremen',
#        'Fortuna Duesseldorf', 'Freiburg', 'Stuttgart', 'Hannover',
#        'Mainz', 'Augsburg', 'Nuernberg'], dtype=object)

# %%
team_data_list[0]['Team'].unique()
# Out:
# array(['Bayern Munich', 'Borussia Dortmund', 'RB Leipzig',
#        'Bayer Leverkusen', 'Borussia M.Gladbach', 'Wolfsburg',
#        'Eintracht Frankfurt', 'Werder Bremen', 'Hoffenheim',
#        'Fortuna Duesseldorf', 'Hertha Berlin', 'Mainz 05', 'Freiburg',
#        'Schalke 04', 'Augsburg', 'VfB Stuttgart', 'Hannover 96',
#        'Nuernberg'], dtype=object)

# %%
for team in team_data_list[0]['Team'].unique():
    if team not in player_data_list[0]['Team'].unique():
        print(team)
# Out:
# Bayern Munich
# RB Leipzig
# Bayer Leverkusen
# Mainz 05
# Schalke 04
# VfB Stuttgart
# Hannover 96

# %%
Team_list = player_data_list[0]['Team']
Team_list

for j in range(len(Team_list)):
    if Team_list[j] == 'Schalke':
        Team_list[j] = 'Schalke 04'
        
    elif Team_list[j] == 'Mainz':
        Team_list[j] = 'Mainz 05'
        
    elif Team_list[j] == 'Bayern':
        Team_list[j] = 'Bayern Munich'

    elif Team_list[j] == 'RBL':
        Team_list[j] = 'RB Leipzig'
        
    elif Team_list[j] == 'Leverkusen':
        Team_list[j] = 'Bayer Leverkusen'
        
    elif Team_list[j] == 'Stuttgart':
        Team_list[j] = 'VfB Stuttgart'
        
    elif Team_list[j] == 'Hannover':
        Team_list[j] = 'Hannover 96'
        
player_data_list[0]['Team'] = pd.DataFrame(Team_list)
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/999082967.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Bayern Munich'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/999082967.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'RB Leipzig'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/999082967.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Bayer Leverkusen'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/999082967.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Schalke 04'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/999082967.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'VfB Stuttgart'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/999082967.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Hannover 96'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/999082967.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Mainz 05'

# %%
for team in team_data_list[0]['Team'].unique():
    if team not in player_data_list[0]['Team'].unique():
        print(team)

# %%
for team in team_data_list[1]['Team'].unique():
    if team not in player_data_list[1]['Team'].unique():
        print(team)
# Out:
# Bayern Munich
# RB Leipzig
# Bayer Leverkusen
# Schalke 04
# Mainz 05

# %%
Team_list = player_data_list[1]['Team']
Team_list

for j in range(len(Team_list)):
    if Team_list[j] == 'Schalke':
        Team_list[j] = 'Schalke 04'
        
    elif Team_list[j] == 'Mainz':
        Team_list[j] = 'Mainz 05'
        
    elif Team_list[j] == 'Bayern':
        Team_list[j] = 'Bayern Munich'

    elif Team_list[j] == 'RBL':
        Team_list[j] = 'RB Leipzig'
        
    elif Team_list[j] == 'Leverkusen':
        Team_list[j] = 'Bayer Leverkusen'
        
player_data_list[1]['Team'] = pd.DataFrame(Team_list)
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/4103700593.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Bayern Munich'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/4103700593.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'RB Leipzig'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/4103700593.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Schalke 04'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/4103700593.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Bayer Leverkusen'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/4103700593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Mainz 05'

# %%
for team in team_data_list[1]['Team'].unique():
    if team not in player_data_list[1]['Team'].unique():
        print(team)

# %%
for team in team_data_list[2]['Team'].unique():
    if team not in player_data_list[2]['Team'].unique():
        print(team)
# Out:
# Bayern Munich
# RB Leipzig
# Bayer Leverkusen
# VfB Stuttgart
# Mainz 05
# Schalke 04

# %%
Team_list = player_data_list[2]['Team']
Team_list

for j in range(len(Team_list)):
    if Team_list[j] == 'Schalke':
        Team_list[j] = 'Schalke 04'
        
    elif Team_list[j] == 'Mainz':
        Team_list[j] = 'Mainz 05'
        
    elif Team_list[j] == 'Bayern':
        Team_list[j] = 'Bayern Munich'

    elif Team_list[j] == 'RBL':
        Team_list[j] = 'RB Leipzig'
        
    elif Team_list[j] == 'Leverkusen':
        Team_list[j] = 'Bayer Leverkusen'
        
    elif Team_list[j] == 'Stuttgart':
        Team_list[j] = 'VfB Stuttgart'
        
    elif Team_list[j] == 'Hannover':
        Team_list[j] = 'Hannover 96'
        
player_data_list[2]['Team'] = pd.DataFrame(Team_list)
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2786216658.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Bayern Munich'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2786216658.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'RB Leipzig'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2786216658.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Bayer Leverkusen'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2786216658.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'VfB Stuttgart'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2786216658.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Schalke 04'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2786216658.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Mainz 05'

# %%
for team in team_data_list[2]['Team'].unique():
    if team not in player_data_list[2]['Team'].unique():
        print(team)

# %%
for team in team_data_list[3]['Team'].unique():
    if team not in player_data_list[3]['Team'].unique():
        print(team)
# Out:
# Bayern Munich
# Bayer Leverkusen
# RB Leipzig
# Mainz 05
# VfB Stuttgart

# %%
Team_list = player_data_list[3]['Team']
Team_list

for j in range(len(Team_list)):
    if Team_list[j] == 'Schalke':
        Team_list[j] = 'Schalke 04'
        
    elif Team_list[j] == 'Mainz':
        Team_list[j] = 'Mainz 05'
        
    elif Team_list[j] == 'Bayern':
        Team_list[j] = 'Bayern Munich'

    elif Team_list[j] == 'RBL':
        Team_list[j] = 'RB Leipzig'
        
    elif Team_list[j] == 'Leverkusen':
        Team_list[j] = 'Bayer Leverkusen'
        
    elif Team_list[j] == 'Stuttgart':
        Team_list[j] = 'VfB Stuttgart'
        
player_data_list[3]['Team'] = pd.DataFrame(Team_list)
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2932556201.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Bayern Munich'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2932556201.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'RB Leipzig'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2932556201.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Bayer Leverkusen'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2932556201.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'VfB Stuttgart'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2932556201.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Mainz 05'

# %%
for team in team_data_list[3]['Team'].unique():
    if team not in player_data_list[3]['Team'].unique():
        print(team)

# %%
for team in team_data_list[4]['Team'].unique():
    if team not in player_data_list[4]['Team'].unique():
        print(team)
# Out:
# Bayern Munich
# RB Leipzig
# Bayer Leverkusen
# Mainz 05
# VfB Stuttgart
# Schalke 04

# %%
Team_list = player_data_list[4]['Team']
Team_list

for j in range(len(Team_list)):
    if Team_list[j] == 'Schalke':
        Team_list[j] = 'Schalke 04'
        
    elif Team_list[j] == 'Mainz':
        Team_list[j] = 'Mainz 05'
        
    elif Team_list[j] == 'Bayern':
        Team_list[j] = 'Bayern Munich'

    elif Team_list[j] == 'RBL':
        Team_list[j] = 'RB Leipzig'
        
    elif Team_list[j] == 'Leverkusen':
        Team_list[j] = 'Bayer Leverkusen'
        
    elif Team_list[j] == 'Stuttgart':
        Team_list[j] = 'VfB Stuttgart'
        
player_data_list[4]['Team'] = pd.DataFrame(Team_list)
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2088056268.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Bayern Munich'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2088056268.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'RB Leipzig'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2088056268.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Bayer Leverkusen'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2088056268.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'VfB Stuttgart'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2088056268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Schalke 04'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2088056268.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Team_list[j] = 'Mainz 05'

# %%
for team in team_data_list[4]['Team'].unique():
    if team not in player_data_list[4]['Team'].unique():
        print(team)

# %% [markdown]
# # Team, Player 데이터 병합

# %%
merged_data_list = []

for i in range(5):
    merged_data_list.append(pd.merge(player_data_list[i], team_data_list[i][['Team', 'Pts']] , on='Team', how='inner'))

# %%
BL_5_seasons_data = pd.concat([merged_data_list[0], merged_data_list[1], merged_data_list[2], merged_data_list[3], merged_data_list[4]])

# %%
BL_5_seasons_data.reset_index().drop('index', axis=1,inplace=True)

# %%
BL_5_seasons_data
# Out:
#                    Name           Team  Age         Position   Apps  Mins  \
# 0    Robert Lewandowski  Bayern Munich   35               FW     33  2959
# 1      Thiago Alcântara  Bayern Munich   33             M(C)  26(4)  2409
# 2        Joshua Kimmich  Bayern Munich   29   D(CR),DMC,M(R)     34  3060
# 3        Kingsley Coman  Bayern Munich   27         M(LR),FW  17(4)  1392
# 4       James Rodríguez  Bayern Munich   32       AM(CLR),FW  13(7)  1143
# ..                  ...            ...  ...              ...    ...   ...
# 281       Mads Pedersen       Augsburg   27       D(L),M(CL)  20(8)  1840
# 282     Elvis Rexhbeçaj       Augsburg   26             M(C)  30(1)  2536
# 283        Robert Gumny       Augsburg   25           D(CLR)  23(6)  2021
# 284    Maximilian Bauer       Augsburg   24             D(C)  20(7)  1845
# 285      Fredrik Jensen       Augsburg   26       AM(CLR),FW  8(12)   922
#
#     Goals Assists Yellow Red  ... Fouled  Off Disp UnsTch  AvgP   PSp Crosses  \
# 0      22       7      2   -  ...    1.4  0.9  1.5    1.5  22.1  77.5       -
# 1       2       6      5   -  ...    1.1    -  0.9    0.9  83.6  91.8     0.5
# 2       2      13      4   -  ...    1.5  0.1  0.7    0.7  74.1  90.5     2.2
# 3       6       4      2   -  ...      2  0.1  1.6    1.6  29.4  85.0     0.7
# 4       7       3      2   -  ...    0.8  0.3  0.6    0.6  43.9  87.1     1.6
# ..    ...     ...    ...  ..  ...    ...  ...  ...    ...   ...   ...     ...
# 281     -       -      6   -  ...    0.8    -  0.5    0.5  17.3  73.8     0.3
# 282     -       -      6   -  ...    1.6    -  0.4    0.4  28.6  69.8       -
# 283     1       2      5   1  ...    0.6    -  0.4    0.4  20.7  66.7     0.1
# 284     -       1      8   -  ...    0.9    -  0.2    0.2  27.7  73.1       -
# 285     2       1      1   -  ...    0.4  0.2    1      1  12.3  58.8     0.3
#
#     LonB ThrB Pts
# 0    0.6  0.2  78
# 1    7.3  0.1  78
# 2    4.2  0.1  78
# 3    0.5    -  78
# 4    2.4  0.2  78
# ..   ...  ...  ..
# 281  0.9    -  34
# 282    1    -  34
# 283  1.2    -  34
# 284    2    -  34
# 285  0.8    -  34
#
# [1396 rows x 34 columns]

# %% [markdown]
# # Position 전처리

# %%
BL_5_seasons_data['Position'].unique()
# Out:
# array([' FW', ' M(C)', ' D(CR),DMC,M(R)', ' M(LR),FW', ' AM(CLR),FW',
#        ' M(CLR),FW', ' D(C)', ' D(CL),M(CL)', ' M(CR)', ' D(CR)',
#        ' D(C),M(C)', ' AM(CL),FW', ' GK', ' AM(LR),FW', ' D(C),M(CL)',
#        ' D(R),M(LR)', ' D(L),M(L)', ' M(LR)', ' D(CR),M(C)',
#        ' D(CL),M(L)', ' AM(CR),FW', ' M(CLR)', ' D(CLR),M(R)',
#        ' D(CR),M(R)', ' DMC', ' D(R),M(CR)', ' D(CR),DMC', ' AM(R),FW',
#        ' D(CR),M(CR)', ' D(R),M(R)', ' D(CL)', ' D(L),DMC,M(L)',
#        ' AM(CLR)', ' D(LR),M(R)', ' D(L),M(CL)', ' D(CLR),DMC',
#        ' D(C),DMC', ' D(CLR)', ' D(R),M(CLR),FW', ' D(LR),M(CLR)',
#        ' M(CR),FW', ' D(C),M(CLR)', ' M(C),FW', ' D(R),M(CLR)',
#        ' D(CLR),DMC,M(R)', ' M(CL)', ' AM(C),FW', ' D(R),DMC,M(R)',
#        ' AM(LR)', ' D(L),M(CR)', ' D(LR),M(LR)', ' D(CLR),DMC,M(LR)',
#        ' D(L),M(LR)', ' D(R),M(C)', ' AM(L),FW', ' D(CL),DMC,M(L)',
#        ' D(R)', ' D(LR)', ' D(L)', ' AM(CL)', ' AM(CR)', ' D(L),M(CLR)',
#        ' M(R)', ' D(LR),DMC,M(LR)', ' D(CLR),M(LR)', ' D(R),M(R),FW',
#        ' D(CLR),DMC,M(L)', ' AM(C)', ' D(R),DMC', ' D(CL),DMC',
#        ' D(LR),M(CL)', ' M(CL),FW', ' Forward', ' M(L)'], dtype=object)

# %%
# 전체 데이터에서 position 데이터만 추출

position_df = BL_5_seasons_data[['Position']]
position_df
# Out:
#             Position
# 0                 FW
# 1               M(C)
# 2     D(CR),DMC,M(R)
# 3           M(LR),FW
# 4         AM(CLR),FW
# ..               ...
# 281       D(L),M(CL)
# 282             M(C)
# 283           D(CLR)
# 284             D(C)
# 285       AM(CLR),FW
#
# [1396 rows x 1 columns]

# %%
# 리스트 형태로 변환

tmp_li = position_df['Position'].tolist()
tmp_li
# Out:
# [' FW',
#  ' M(C)',
#  ' D(CR),DMC,M(R)',
#  ' M(LR),FW',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' AM(CLR),FW',
#  ' D(CL),M(CL)',
#  ' M(CR)',
#  ' D(CR)',
#  ' D(C),M(C)',
#  ' D(CR)',
#  ' AM(CL),FW',
#  ' M(CR)',
#  ' GK',
#  ' M(C)',
#  ' AM(LR),FW',
#  ' AM(CLR),FW',
#  ' AM(CLR),FW',
#  ' D(C),M(CL)',
#  ' D(R),M(LR)',
#  ' D(L),M(L)',
#  ' D(CR)',
#  ' D(C)',
#  ' GK',
#  ' FW',
#  ' M(LR)',
#  ' M(CLR),FW',
#  ' D(CR),M(C)',
#  ' D(CL),M(L)',
#  ' D(C)',
#  ' AM(CR),FW',
#  ' D(C)',
#  ' AM(CLR),FW',
#  ' M(CLR)',
#  ' AM(CLR),FW',
#  ' D(CLR),M(R)',
#  ' D(CR),M(R)',
#  ' M(CLR),FW',
#  ' GK',
#  ' DMC',
#  ' D(R),M(CR)',
#  ' D(CR),DMC',
#  ' AM(CL),FW',
#  ' AM(R),FW',
#  ' FW',
#  ' M(LR),FW',
#  ' FW',
#  ' AM(CLR),FW',
#  ' D(CR),M(CR)',
#  ' D(R),M(R)',
#  ' GK',
#  ' M(CLR)',
#  ' D(C)',
#  ' D(CL)',
#  ' DMC',
#  ' M(CLR)',
#  ' D(L),DMC,M(L)',
#  ' AM(CLR)',
#  ' D(CR),M(R)',
#  ' M(CLR),FW',
#  ' DMC',
#  ' D(C),M(C)',
#  ' D(LR),M(R)',
#  ' D(L),M(CL)',
#  ' M(CLR),FW',
#  ' AM(R),FW',
#  ' D(CL)',
#  ' D(CL)',
#  ' M(CLR),FW',
#  ' D(CLR),DMC',
#  ' D(C),DMC',
#  ' GK',
#  ' AM(CLR),FW',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' M(CLR),FW',
#  ' D(CLR)',
#  ' GK',
#  ' AM(CLR),FW',
#  ' D(R),M(CLR),FW',
#  ' D(CR),DMC',
#  ' M(C)',
#  ' D(L),M(L)',
#  ' D(CR),DMC',
#  ' M(C)',
#  ' D(R),M(R)',
#  ' D(C),DMC',
#  ' M(LR),FW',
#  ' D(LR),M(CLR)',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' M(CR),FW',
#  ' M(C)',
#  ' DMC',
#  ' D(CR),M(CR)',
#  ' D(C)',
#  ' D(CL),M(L)',
#  ' M(CLR),FW',
#  ' M(CLR),FW',
#  ' D(C),M(C)',
#  ' D(R),M(R)',
#  ' FW',
#  ' D(CR)',
#  ' GK',
#  ' D(C),DMC',
#  ' D(R),M(CLR),FW',
#  ' D(C),DMC',
#  ' D(CL),M(L)',
#  ' D(C),M(CLR)',
#  ' AM(CR),FW',
#  ' M(C)',
#  ' GK',
#  ' AM(CLR),FW',
#  ' D(CR),M(C)',
#  ' M(CLR)',
#  ' D(C)',
#  ' GK',
#  ' AM(CR),FW',
#  ' D(R),M(CR)',
#  ' AM(LR),FW',
#  ' DMC',
#  ' M(C),FW',
#  ' D(R),M(CLR)',
#  ' D(L),M(CL)',
#  ' D(C),DMC',
#  ' AM(CLR),FW',
#  ' GK',
#  ' FW',
#  ' M(CLR)',
#  ' FW',
#  ' M(CR)',
#  ' D(C),M(C)',
#  ' D(L),M(L)',
#  ' D(CL)',
#  ' AM(CLR)',
#  ' FW',
#  ' M(CR)',
#  ' D(LR),M(R)',
#  ' D(L),M(L)',
#  ' D(C),M(C)',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' GK',
#  ' D(C)',
#  ' D(L),M(CL)',
#  ' AM(R),FW',
#  ' AM(CLR),FW',
#  ' M(CLR)',
#  ' M(C)',
#  ' M(CLR),FW',
#  ' M(CLR),FW',
#  ' D(CLR),DMC,M(R)',
#  ' AM(CLR),FW',
#  ' M(CR)',
#  ' M(C)',
#  ' M(CL)',
#  ' D(L),M(L)',
#  ' GK',
#  ' D(C)',
#  ' AM(CLR),FW',
#  ' D(C)',
#  ' D(C),DMC',
#  ' M(LR),FW',
#  ' M(CR)',
#  ' AM(C),FW',
#  ' AM(CR),FW',
#  ' M(CL)',
#  ' D(R),DMC,M(R)',
#  ' AM(CLR),FW',
#  ' D(CR),DMC',
#  ' D(CL),M(L)',
#  ' M(CL)',
#  ' AM(LR),FW',
#  ' GK',
#  ' FW',
#  ' AM(CLR),FW',
#  ' D(C),M(C)',
#  ' D(C),DMC',
#  ' D(R),M(R)',
#  ' AM(LR)',
#  ' D(C)',
#  ' FW',
#  ' M(CLR),FW',
#  ' AM(CLR),FW',
#  ' D(CL)',
#  ' D(C),DMC',
#  ' GK',
#  ' D(C),DMC',
#  ' D(C)',
#  ' D(L),M(L)',
#  ' D(CR),M(R)',
#  ' M(CR)',
#  ' M(CLR),FW',
#  ' AM(CR),FW',
#  ' AM(CLR),FW',
#  ' D(C)',
#  ' D(C)',
#  ' M(CLR),FW',
#  ' D(CLR),M(R)',
#  ' D(CL),M(L)',
#  ' FW',
#  ' AM(CR),FW',
#  ' M(CLR)',
#  ' D(L),M(CR)',
#  ' DMC',
#  ' GK',
#  ' D(LR),M(R)',
#  ' AM(CR),FW',
#  ' AM(CLR),FW',
#  ' M(CLR)',
#  ' GK',
#  ' M(C)',
#  ' FW',
#  ' DMC',
#  ' D(CR),DMC',
#  ' M(CLR)',
#  ' D(C)',
#  ' M(CLR),FW',
#  ' D(CLR),DMC,M(R)',
#  ' M(CL)',
#  ' D(L),DMC,M(L)',
#  ' M(C)',
#  ' D(CL)',
#  ' D(L),M(L)',
#  ' AM(C),FW',
#  ' D(L),M(L)',
#  ' FW',
#  ' AM(CL),FW',
#  ' D(CR)',
#  ' AM(CLR),FW',
#  ' D(CR),DMC',
#  ' DMC',
#  ' M(C)',
#  ' D(CL)',
#  ' M(CLR),FW',
#  ' D(LR),M(LR)',
#  ' GK',
#  ' FW',
#  ' AM(CLR),FW',
#  ' D(R),M(CLR)',
#  ' D(C),DMC',
#  ' AM(CLR),FW',
#  ' D(C)',
#  ' FW',
#  ' D(L),M(L)',
#  ' D(C)',
#  ' AM(CR),FW',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' M(C)',
#  ' M(CLR)',
#  ' AM(CL),FW',
#  ' D(C)',
#  ' AM(CLR),FW',
#  ' GK',
#  ' D(C)',
#  ' D(C),M(C)',
#  ' M(C),FW',
#  ' D(L),M(CL)',
#  ' D(C),DMC',
#  ' D(C)',
#  ' FW',
#  ' D(C),DMC',
#  ' D(CLR),DMC,M(LR)',
#  ' AM(CLR),FW',
#  ' AM(LR)',
#  ' AM(CL),FW',
#  ' M(CLR),FW',
#  ' FW',
#  ' D(L),M(LR)',
#  ' AM(CLR),FW',
#  ' M(C)',
#  ' M(CLR),FW',
#  ' D(CR),DMC,M(R)',
#  ' M(CLR)',
#  ' D(CLR),M(R)',
#  ' M(CR)',
#  ' M(LR),FW',
#  ' D(CL),M(CL)',
#  ' D(CR)',
#  ' M(CLR),FW',
#  ' GK',
#  ' D(CL)',
#  ' AM(CLR)',
#  ' M(CLR),FW',
#  ' D(L),M(CL)',
#  ' D(LR),M(R)',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' M(CLR),FW',
#  ' D(C),M(C)',
#  ' D(CR),M(R)',
#  ' D(CLR),DMC',
#  ' GK',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' M(CLR),FW',
#  ' D(CL),M(L)',
#  ' D(CR),M(R)',
#  ' D(C)',
#  ' AM(R),FW',
#  ' D(R),M(CR)',
#  ' D(CLR),M(R)',
#  ' AM(CR),FW',
#  ' AM(CLR),FW',
#  ' DMC',
#  ' GK',
#  ' M(CLR)',
#  ' M(LR),FW',
#  ' FW',
#  ' D(C)',
#  ' D(R),M(R)',
#  ' D(CR),M(R)',
#  ' FW',
#  ' FW',
#  ' D(R),M(LR)',
#  ' AM(CLR),FW',
#  ' D(R),M(C)',
#  ' D(C),DMC',
#  ' D(C)',
#  ' GK',
#  ' M(C)',
#  ' D(CL)',
#  ' D(CR),M(CR)',
#  ' M(CLR)',
#  ' D(R),M(R)',
#  ' FW',
#  ' M(CR)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(C),M(C)',
#  ' D(L),M(L)',
#  ' D(C)',
#  ' M(C)',
#  ' AM(CLR),FW',
#  ' GK',
#  ' M(CLR),FW',
#  ' D(L),M(CL)',
#  ' M(CLR)',
#  ' AM(R),FW',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' D(C),DMC',
#  ' D(R),M(CLR),FW',
#  ' AM(CLR),FW',
#  ' D(C)',
#  ' D(CL),M(L)',
#  ' D(C),M(CLR)',
#  ' AM(LR),FW',
#  ' D(LR),M(R)',
#  ' GK',
#  ' M(CLR)',
#  ' AM(LR),FW',
#  ' FW',
#  ' AM(LR),FW',
#  ' AM(L),FW',
#  ' AM(CLR),FW',
#  ' D(C),DMC',
#  ' D(CL),DMC,M(L)',
#  ' M(C)',
#  ' D(R),M(CLR),FW',
#  ' D(CLR)',
#  ' M(CLR),FW',
#  ' AM(CR),FW',
#  ' D(CR),DMC',
#  ' GK',
#  ' D(R),M(R)',
#  ' M(LR),FW',
#  ' D(CR),DMC',
#  ' M(C)',
#  ' M(C)',
#  ' D(L),M(L)',
#  ' M(CR),FW',
#  ' AM(CLR),FW',
#  ' D(C),M(C)',
#  ' D(CR),M(CR)',
#  ' M(CLR),FW',
#  ' M(CLR),FW',
#  ' M(C)',
#  ' D(C)',
#  ' D(CL),M(L)',
#  ' D(R),M(R)',
#  ' M(CLR)',
#  ' M(C)',
#  ' GK',
#  ' M(CLR),FW',
#  ' FW',
#  ' DMC',
#  ' AM(CLR),FW',
#  ' D(L),M(LR)',
#  ' D(R),M(LR)',
#  ' M(CLR),FW',
#  ' D(R),M(CR)',
#  ' D(CR)',
#  ' D(C),M(CL)',
#  ' GK',
#  ' AM(CLR),FW',
#  ' D(C)',
#  ' DMC',
#  ' D(C)',
#  ' D(CR),M(R)',
#  ' M(C)',
#  ' D(CR),M(R)',
#  ' FW',
#  ' D(L),M(L)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(C),M(C)',
#  ' D(R),M(CLR),FW',
#  ' GK',
#  ' D(C)',
#  ' AM(CR),FW',
#  ' D(C)',
#  ' FW',
#  ' D(C)',
#  ' D(CL)',
#  ' D(L),M(CL)',
#  ' DMC',
#  ' AM(CLR),FW',
#  ' D(L),M(L)',
#  ' M(CLR),FW',
#  ' GK',
#  ' AM(CLR)',
#  ' M(CR)',
#  ' D(CR),M(R)',
#  ' D(R),M(CLR)',
#  ' FW',
#  ' D(C),DMC',
#  ' FW',
#  ' AM(CR),FW',
#  ' D(L),M(L)',
#  ' D(C)',
#  ' D(CLR)',
#  ' AM(CLR),FW',
#  ' M(C)',
#  ' D(R),M(R)',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' D(C),DMC',
#  ' FW',
#  ' GK',
#  ' D(R),M(R)',
#  ' D(C),DMC',
#  ' AM(CR),FW',
#  ' D(CL)',
#  ' M(C)',
#  ' AM(C),FW',
#  ' GK',
#  ' D(C),DMC',
#  ' AM(CL),FW',
#  ' D(R)',
#  ' AM(R),FW',
#  ' D(LR)',
#  ' AM(L),FW',
#  ' AM(CLR)',
#  ' M(CLR),FW',
#  ' D(L),M(LR)',
#  ' AM(CLR),FW',
#  ' D(CLR),DMC,M(R)',
#  ' AM(CLR),FW',
#  ' M(CL)',
#  ' D(CL),M(L)',
#  ' D(C)',
#  ' M(CR)',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' GK',
#  ' D(C),DMC',
#  ' AM(C),FW',
#  ' FW',
#  ' D(L),M(CL)',
#  ' M(CLR)',
#  ' DMC',
#  ' D(L)',
#  ' D(R),M(R)',
#  ' D(L),M(L)',
#  ' D(C)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' GK',
#  ' D(CLR)',
#  ' FW',
#  ' FW',
#  ' D(C),DMC',
#  ' AM(CL)',
#  ' D(C)',
#  ' D(R),M(CLR)',
#  ' FW',
#  ' AM(CLR),FW',
#  ' D(CL)',
#  ' D(L),M(L)',
#  ' GK',
#  ' D(C),DMC',
#  ' D(C)',
#  ' M(CLR),FW',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' AM(CR)',
#  ' M(CLR),FW',
#  ' M(CLR),FW',
#  ' D(LR),M(LR)',
#  ' D(R),M(CR)',
#  ' AM(CL),FW',
#  ' AM(CLR),FW',
#  ' GK',
#  ' D(CR),DMC',
#  ' DMC',
#  ' M(CLR)',
#  ' D(CL)',
#  ' D(L),M(L)',
#  ' M(C)',
#  ' DMC',
#  ' FW',
#  ' D(CR),M(CR)',
#  ' FW',
#  ' M(CLR)',
#  ' AM(CLR),FW',
#  ' M(CL)',
#  ' FW',
#  ' D(C),DMC',
#  ' D(CL),M(L)',
#  ' GK',
#  ' D(CR),DMC',
#  ' D(R),DMC,M(R)',
#  ' GK',
#  ' D(C),M(C)',
#  ' D(CL),M(L)',
#  ' AM(CLR),FW',
#  ' D(C),DMC',
#  ' D(R),M(R)',
#  ' DMC',
#  ' FW',
#  ' D(CR),DMC,M(R)',
#  ' M(CLR),FW',
#  ' M(CR)',
#  ' AM(CLR),FW',
#  ' M(LR),FW',
#  ' D(L),M(LR)',
#  ' D(CL)',
#  ' D(CR)',
#  ' M(CLR),FW',
#  ' D(CLR),M(R)',
#  ' D(CL),M(CL)',
#  ' M(CLR)',
#  ' D(CR)',
#  ' GK',
#  ' M(CLR),FW',
#  ' D(C),M(C)',
#  ' FW',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(L),M(CL)',
#  ' M(CLR),FW',
#  ' D(CLR),DMC',
#  ' D(CLR),DMC',
#  ' AM(CLR)',
#  ' M(C)',
#  ' M(CLR)',
#  ' DMC',
#  ' D(R),M(R)',
#  ' M(CLR),FW',
#  ' GK',
#  ' FW',
#  ' M(LR),FW',
#  ' D(C)',
#  ' AM(CLR),FW',
#  ' D(CL)',
#  ' M(C)',
#  ' AM(CL)',
#  ' D(LR),M(LR)',
#  ' D(CR),M(CR)',
#  ' D(R),M(C)',
#  ' D(C)',
#  ' GK',
#  ' FW',
#  ' M(CR)',
#  ' D(L),M(CLR)',
#  ' D(CR),DMC',
#  ' AM(CL),FW',
#  ' FW',
#  ' D(L),M(CL)',
#  ' M(C)',
#  ' DMC',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' AM(CLR),FW',
#  ' GK',
#  ' D(LR),M(R)',
#  ' D(C),DMC',
#  ' FW',
#  ' D(LR),M(R)',
#  ' FW',
#  ' M(CR)',
#  ' D(C)',
#  ' D(R),M(R)',
#  ' D(R),M(CR)',
#  ' M(C)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(L),M(L)',
#  ' AM(CLR),FW',
#  ' D(L),M(CL)',
#  ' GK',
#  ' D(C),M(C)',
#  ' D(L),M(L)',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' M(CLR)',
#  ' FW',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' D(L),M(L)',
#  ' M(CLR),FW',
#  ' AM(CLR),FW',
#  ' D(C)',
#  ' D(CL),M(L)',
#  ' M(CLR)',
#  ' D(CR),M(R)',
#  ' AM(CR),FW',
#  ' AM(CLR),FW',
#  ' AM(R),FW',
#  ' D(R),M(CR)',
#  ' M(CLR)',
#  ' D(CLR),M(R)',
#  ' GK',
#  ' AM(CLR),FW',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' M(CLR),FW',
#  ' AM(CL),FW',
#  ' AM(R),FW',
#  ' FW',
#  ' D(C)',
#  ' M(C)',
#  ' M(CLR)',
#  ' D(CL),M(L)',
#  ' D(L),M(CL)',
#  ' M(C)',
#  ' D(CR)',
#  ' D(C),M(C)',
#  ' GK',
#  ' M(CLR),FW',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' AM(CLR),FW',
#  ' DMC',
#  ' D(C),M(CL)',
#  ' D(R),M(LR)',
#  ' D(L),M(LR)',
#  ' D(CR)',
#  ' GK',
#  ' AM(C),FW',
#  ' D(R),M(CR)',
#  ' D(L),M(LR)',
#  ' AM(CLR),FW',
#  ' D(CR),M(C)',
#  ' M(CLR)',
#  ' M(CLR),FW',
#  ' D(L),M(L)',
#  ' DMC',
#  ' FW',
#  ' D(CR)',
#  ' M(C)',
#  ' D(C)',
#  ' GK',
#  ' D(CR),DMC',
#  ' D(L),M(CR)',
#  ' AM(CR),FW',
#  ' M(CLR),FW',
#  ' M(CLR),FW',
#  ' M(C)',
#  ' D(C),DMC',
#  ' M(R)',
#  ' AM(C),FW',
#  ' D(CR),M(R)',
#  ' D(R),M(CLR),FW',
#  ' M(CLR),FW',
#  ' D(CLR)',
#  ' AM(L),FW',
#  ' M(C)',
#  ' D(CR),DMC',
#  ' AM(CLR),FW',
#  ' D(CL),DMC,M(L)',
#  ' D(R),M(R)',
#  ' M(C)',
#  ' AM(CR),FW',
#  ' D(C),DMC',
#  ' D(R),M(CLR)',
#  ' GK',
#  ' M(LR),FW',
#  ' M(CLR)',
#  ' D(L),M(L)',
#  ' AM(CL)',
#  ' D(C),DMC',
#  ' DMC',
#  ' D(L),M(L)',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' D(R),M(CLR)',
#  ' GK',
#  ' D(C)',
#  ' AM(CL),FW',
#  ' D(C)',
#  ' D(CL)',
#  ' D(CLR),M(R)',
#  ' AM(CR),FW',
#  ' FW',
#  ' D(R),M(CLR),FW',
#  ' D(C)',
#  ' GK',
#  ' AM(CLR),FW',
#  ' D(L),M(L)',
#  ' D(C)',
#  ' AM(CLR),FW',
#  ' D(C),DMC',
#  ' AM(CR),FW',
#  ' D(R),M(R)',
#  ' D(C),DMC',
#  ' M(CLR),FW',
#  ' DMC',
#  ' D(CR),DMC',
#  ' AM(CR),FW',
#  ' D(CLR)',
#  ' D(CR),M(R)',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' D(L),M(L)',
#  ' D(C),M(C)',
#  ' AM(CLR),FW',
#  ' GK',
#  ' M(C)',
#  ' D(C)',
#  ' FW',
#  ' FW',
#  ' AM(CR),FW',
#  ' M(CLR)',
#  ' D(R),M(CLR),FW',
#  ' AM(CLR),FW',
#  ' D(LR),M(CLR)',
#  ' D(C),DMC',
#  ' D(C)',
#  ' M(CLR),FW',
#  ' FW',
#  ' D(C)',
#  ' GK',
#  ' D(CR)',
#  ' M(C)',
#  ' D(L),M(L)',
#  ' M(CLR)',
#  ' AM(LR),FW',
#  ' D(C)',
#  ' AM(CL),FW',
#  ' DMC',
#  ' FW',
#  ' D(R),M(R)',
#  ' DMC',
#  ' M(C),FW',
#  ' D(L),M(CL)',
#  ' D(C)',
#  ' D(C)',
#  ' M(C)',
#  ' D(R),M(CLR)',
#  ' D(L)',
#  ' D(R),M(R)',
#  ' GK',
#  ' AM(CLR)',
#  ' D(L),M(L)',
#  ' D(CL),M(L)',
#  ' M(C)',
#  ' M(CLR),FW',
#  ' D(L),M(L)',
#  ' AM(CLR),FW',
#  ' D(CLR),DMC,M(R)',
#  ' M(CR)',
#  ' D(C)',
#  ' FW',
#  ' M(CLR),FW',
#  ' AM(CLR),FW',
#  ' GK',
#  ' D(CL),M(L)',
#  ' D(C),DMC',
#  ' M(CR)',
#  ' D(C),DMC',
#  ' D(R),DMC,M(R)',
#  ' FW',
#  ' AM(CLR),FW',
#  ' D(C)',
#  ' AM(CLR),FW',
#  ' AM(CLR),FW',
#  ' GK',
#  ' M(CLR)',
#  ' AM(CR),FW',
#  ' D(CR),M(C)',
#  ' D(C)',
#  ' D(C),DMC',
#  ' FW',
#  ' D(CR),M(R)',
#  ' D(CL),M(L)',
#  ' AM(LR),FW',
#  ' M(CLR)',
#  ' D(CR),DMC',
#  ' DMC',
#  ' D(C)',
#  ' D(LR),M(LR)',
#  ' AM(CL),FW',
#  ' GK',
#  ' D(CL)',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' M(C)',
#  ' AM(CR),FW',
#  ' D(LR),M(LR)',
#  ' M(CL)',
#  ' FW',
#  ' FW',
#  ' D(CR),DMC,M(R)',
#  ' M(CLR),FW',
#  ' D(L),M(LR)',
#  ' AM(CLR),FW',
#  ' M(CLR),FW',
#  ' M(LR),FW',
#  ' M(CR)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(CL)',
#  ' D(CLR),M(R)',
#  ' D(CR)',
#  ' GK',
#  ' D(C)',
#  ' M(CLR),FW',
#  ' M(CLR),FW',
#  ' M(CLR),FW',
#  ' D(C)',
#  ' D(CL)',
#  ' D(L),M(L)',
#  ' D(CR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' D(CR),M(R)',
#  ' FW',
#  ' AM(CLR),FW',
#  ' D(CLR),M(R)',
#  ' D(LR),DMC,M(LR)',
#  ' D(R),M(CR)',
#  ' AM(CLR),FW',
#  ' M(CLR)',
#  ' GK',
#  ' AM(CR),FW',
#  ' D(R),M(CR)',
#  ' FW',
#  ' M(CLR),FW',
#  ' M(CLR)',
#  ' M(CLR),FW',
#  ' AM(LR),FW',
#  ' D(R),M(R)',
#  ' D(C)',
#  ' D(CLR),DMC',
#  ' M(C)',
#  ' D(L),M(CL)',
#  ' M(CLR),FW',
#  ' D(CLR),DMC',
#  ' GK',
#  ' D(C),M(C)',
#  ' D(R),M(CLR)',
#  ' D(C)',
#  ' AM(R),FW',
#  ' AM(CL),FW',
#  ' M(CLR),FW',
#  ' M(C)',
#  ' D(C)',
#  ' D(R),M(R)',
#  ' D(C)',
#  ' GK',
#  ' D(C),M(C)',
#  ' AM(CLR),FW',
#  ' D(CL),M(L)',
#  ' M(C)',
#  ' D(L),M(L)',
#  ' M(C)',
#  ' AM(CLR),FW',
#  ' D(CR)',
#  ' FW',
#  ' D(C)',
#  ' AM(CL)',
#  ' D(C),DMC',
#  ' AM(CLR),FW',
#  ' D(C)',
#  ' D(CLR),M(R)',
#  ' D(L),M(L)',
#  ' GK',
#  ' M(CR)',
#  ' AM(LR)',
#  ' M(CLR),FW',
#  ' AM(CR),FW',
#  ' FW',
#  ' D(C)',
#  ' M(CLR),FW',
#  ' AM(CL),FW',
#  ' D(R),M(CLR),FW',
#  ' DMC',
#  ' AM(CLR),FW',
#  ' AM(CR),FW',
#  ' D(CL),DMC,M(L)',
#  ' M(C)',
#  ' D(CR),DMC',
#  ' GK',
#  ' M(CLR),FW',
#  ' D(CLR)',
#  ' AM(L),FW',
#  ' D(CLR),M(LR)',
#  ' D(L),M(L)',
#  ' D(R),M(R)',
#  ' M(LR),FW',
#  ' M(C)',
#  ' D(L),M(LR)',
#  ' AM(CLR),FW',
#  ' D(C),M(CL)',
#  ' M(CLR),FW',
#  ' DMC',
#  ' D(C),DMC',
#  ' AM(C),FW',
#  ' GK',
#  ' AM(CLR),FW',
#  ' M(C)',
#  ' D(R),M(LR)',
#  ' D(CR)',
#  ' AM(C),FW',
#  ' DMC',
#  ' D(CR),M(R)',
#  ' D(R),M(CR)',
#  ' D(CR),M(C)',
#  ' AM(CLR),FW',
#  ' M(LR),FW',
#  ' D(CL)',
#  ' AM(C),FW',
#  ' AM(CLR),FW',
#  ' D(C)',
#  ' M(C)',
#  ' GK',
#  ' AM(CLR),FW',
#  ' D(C)',
#  ' D(CR),M(CR)',
#  ' D(CR),DMC',
#  ' D(R),M(C)',
#  ' M(CLR)',
#  ' D(R),M(LR)',
#  ' AM(CLR)',
#  ' FW',
#  ' FW',
#  ' D(C)',
#  ' AM(CR),FW',
#  ' DMC',
#  ' D(L),M(CL)',
#  ' M(CLR)',
#  ' M(C)',
#  ' GK',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' M(C),FW',
#  ' M(CLR),FW',
#  ' FW',
#  ' AM(CR)',
#  ' D(R),M(R),FW',
#  ' D(L),M(L)',
#  ' D(C),DMC',
#  ' GK',
#  ' D(R),M(R)',
#  ' AM(R),FW',
#  ' D(L),M(LR)',
#  ' D(C),DMC',
#  ' D(C)',
#  ' D(C),M(C)',
#  ' D(CLR),DMC,M(L)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' AM(CLR),FW',
#  ' M(C)',
#  ' D(LR),M(LR)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' D(L),M(L)',
#  ' AM(CL),FW',
#  ' DMC',
#  ' M(CLR),FW',
#  ' D(C),DMC',
#  ' D(CR),DMC',
#  ' D(CL)',
#  ' M(C)',
#  ' M(CLR),FW',
#  ' GK',
#  ' M(R)',
#  ' M(CLR),FW',
#  ' M(CR)',
#  ' D(C)',
#  ...]

# %%
# 포지션이 여러 개인 경우 하나의 포지션만 남긴다.

for i in range(len(tmp_li)):
    tmp = tmp_li[i]
    if ',' in tmp:
        tmp_li[i] = tmp.split(',')[0]

# %%
tmp = pd.DataFrame(tmp_li)
tmp.columns = ['Position']
tmp
# Out:
#       Position
# 0           FW
# 1         M(C)
# 2        D(CR)
# 3        M(LR)
# 4      AM(CLR)
# ...        ...
# 1391      D(L)
# 1392      M(C)
# 1393    D(CLR)
# 1394      D(C)
# 1395   AM(CLR)
#
# [1396 rows x 1 columns]

# %%
# 전체 데이터에 새로운 포지션 값 적용

BL_5_seasons_data['Position'] = tmp['Position']
BL_5_seasons_data['Position'] # 변경이 되었는지 확인
# Out:
# 0            FW
# 1          M(C)
# 2         D(CR)
# 3         M(LR)
# 4       AM(CLR)
#          ...
# 281       D(CR)
# 282      M(CLR)
# 283          GK
# 284       D(CL)
# 285     AM(CLR)
# Name: Position, Length: 1396, dtype: object

# %%
# unique값 확인
# 공백이 있는 경우 같은 포지션도 다르게 판단 -> 공백을 지워준다.

tmp_li = BL_5_seasons_data['Position'].tolist()
tmp_li
# Out:
# [' FW',
#  ' M(C)',
#  ' D(CR)',
#  ' M(LR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(CL)',
#  ' M(CR)',
#  ' D(CR)',
#  ' D(C)',
#  ' D(CR)',
#  ' AM(CL)',
#  ' M(CR)',
#  ' GK',
#  ' M(C)',
#  ' AM(LR)',
#  ' AM(CLR)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(R)',
#  ' D(L)',
#  ' D(CR)',
#  ' D(C)',
#  ' GK',
#  ' FW',
#  ' M(LR)',
#  ' M(CLR)',
#  ' D(CR)',
#  ' D(CL)',
#  ' D(C)',
#  ' AM(CR)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' AM(CLR)',
#  ' D(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' GK',
#  ' DMC',
#  ' D(R)',
#  ' D(CR)',
#  ' AM(CL)',
#  ' AM(R)',
#  ' FW',
#  ' M(LR)',
#  ' FW',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' D(R)',
#  ' GK',
#  ' M(CLR)',
#  ' D(C)',
#  ' D(CL)',
#  ' DMC',
#  ' M(CLR)',
#  ' D(L)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' DMC',
#  ' D(C)',
#  ' D(LR)',
#  ' D(L)',
#  ' M(CLR)',
#  ' AM(R)',
#  ' D(CL)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' D(C)',
#  ' GK',
#  ' AM(CLR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' GK',
#  ' AM(CLR)',
#  ' D(R)',
#  ' D(CR)',
#  ' M(C)',
#  ' D(L)',
#  ' D(CR)',
#  ' M(C)',
#  ' D(R)',
#  ' D(C)',
#  ' M(LR)',
#  ' D(LR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(CR)',
#  ' M(C)',
#  ' DMC',
#  ' D(CR)',
#  ' D(C)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' D(R)',
#  ' FW',
#  ' D(CR)',
#  ' GK',
#  ' D(C)',
#  ' D(R)',
#  ' D(C)',
#  ' D(CL)',
#  ' D(C)',
#  ' AM(CR)',
#  ' M(C)',
#  ' GK',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' GK',
#  ' AM(CR)',
#  ' D(R)',
#  ' AM(LR)',
#  ' DMC',
#  ' M(C)',
#  ' D(R)',
#  ' D(L)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' GK',
#  ' FW',
#  ' M(CLR)',
#  ' FW',
#  ' M(CR)',
#  ' D(C)',
#  ' D(L)',
#  ' D(CL)',
#  ' AM(CLR)',
#  ' FW',
#  ' M(CR)',
#  ' D(LR)',
#  ' D(L)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(C)',
#  ' GK',
#  ' D(C)',
#  ' D(L)',
#  ' AM(R)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(C)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' AM(CLR)',
#  ' M(CR)',
#  ' M(C)',
#  ' M(CL)',
#  ' D(L)',
#  ' GK',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' M(LR)',
#  ' M(CR)',
#  ' AM(C)',
#  ' AM(CR)',
#  ' M(CL)',
#  ' D(R)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' D(CL)',
#  ' M(CL)',
#  ' AM(LR)',
#  ' GK',
#  ' FW',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' D(R)',
#  ' AM(LR)',
#  ' D(C)',
#  ' FW',
#  ' M(CLR)',
#  ' AM(CLR)',
#  ' D(CL)',
#  ' D(C)',
#  ' GK',
#  ' D(C)',
#  ' D(C)',
#  ' D(L)',
#  ' D(CR)',
#  ' M(CR)',
#  ' M(CLR)',
#  ' AM(CR)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' D(CL)',
#  ' FW',
#  ' AM(CR)',
#  ' M(CLR)',
#  ' D(L)',
#  ' DMC',
#  ' GK',
#  ' D(LR)',
#  ' AM(CR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' GK',
#  ' M(C)',
#  ' FW',
#  ' DMC',
#  ' D(CR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' M(CL)',
#  ' D(L)',
#  ' M(C)',
#  ' D(CL)',
#  ' D(L)',
#  ' AM(C)',
#  ' D(L)',
#  ' FW',
#  ' AM(CL)',
#  ' D(CR)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' DMC',
#  ' M(C)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' D(LR)',
#  ' GK',
#  ' FW',
#  ' AM(CLR)',
#  ' D(R)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' FW',
#  ' D(L)',
#  ' D(C)',
#  ' AM(CR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' M(C)',
#  ' M(CLR)',
#  ' AM(CL)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' GK',
#  ' D(C)',
#  ' D(C)',
#  ' M(C)',
#  ' D(L)',
#  ' D(C)',
#  ' D(C)',
#  ' FW',
#  ' D(C)',
#  ' D(CLR)',
#  ' AM(CLR)',
#  ' AM(LR)',
#  ' AM(CL)',
#  ' M(CLR)',
#  ' FW',
#  ' M(C)',
#  ' D(CR)',
#  ' M(LR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(CL)',
#  ' M(CR)',
#  ' D(CR)',
#  ' D(C)',
#  ' D(CR)',
#  ' AM(CL)',
#  ' M(CR)',
#  ' GK',
#  ' M(C)',
#  ' AM(LR)',
#  ' AM(CLR)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(R)',
#  ' D(L)',
#  ' D(CR)',
#  ' D(C)',
#  ' GK',
#  ' FW',
#  ' M(LR)',
#  ' M(CLR)',
#  ' D(CR)',
#  ' D(CL)',
#  ' D(C)',
#  ' AM(CR)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' AM(CLR)',
#  ' D(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' GK',
#  ' DMC',
#  ' D(R)',
#  ' D(CR)',
#  ' AM(CL)',
#  ' AM(R)',
#  ' FW',
#  ' M(LR)',
#  ' FW',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' D(R)',
#  ' GK',
#  ' M(CLR)',
#  ' D(C)',
#  ' D(CL)',
#  ' DMC',
#  ' M(CLR)',
#  ' D(L)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' DMC',
#  ' D(C)',
#  ' D(LR)',
#  ' D(L)',
#  ' M(CLR)',
#  ' AM(R)',
#  ' D(CL)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' D(C)',
#  ' GK',
#  ' AM(CLR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' GK',
#  ' AM(CLR)',
#  ' D(R)',
#  ' D(CR)',
#  ' M(C)',
#  ' D(L)',
#  ' D(CR)',
#  ' M(C)',
#  ' D(R)',
#  ' D(C)',
#  ' M(LR)',
#  ' D(LR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(CR)',
#  ' M(C)',
#  ' DMC',
#  ' D(CR)',
#  ' D(C)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' D(R)',
#  ' FW',
#  ' D(CR)',
#  ' GK',
#  ' D(C)',
#  ' D(R)',
#  ' D(C)',
#  ' D(CL)',
#  ' D(C)',
#  ' AM(CR)',
#  ' M(C)',
#  ' GK',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' GK',
#  ' AM(CR)',
#  ' D(R)',
#  ' AM(LR)',
#  ' DMC',
#  ' M(C)',
#  ' D(R)',
#  ' D(L)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' GK',
#  ' FW',
#  ' M(CLR)',
#  ' FW',
#  ' M(CR)',
#  ' D(C)',
#  ' D(L)',
#  ' D(CL)',
#  ' AM(CLR)',
#  ' FW',
#  ' M(CR)',
#  ' D(LR)',
#  ' D(L)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(C)',
#  ' GK',
#  ' D(C)',
#  ' D(L)',
#  ' AM(R)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(C)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' AM(CLR)',
#  ' M(CR)',
#  ' M(C)',
#  ' M(CL)',
#  ' D(L)',
#  ' GK',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' M(LR)',
#  ' M(CR)',
#  ' AM(C)',
#  ' AM(CR)',
#  ' M(CL)',
#  ' D(R)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' D(CL)',
#  ' M(CL)',
#  ' AM(LR)',
#  ' GK',
#  ' FW',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' D(R)',
#  ' AM(LR)',
#  ' D(C)',
#  ' FW',
#  ' M(CLR)',
#  ' AM(CLR)',
#  ' D(CL)',
#  ' D(C)',
#  ' GK',
#  ' D(C)',
#  ' D(C)',
#  ' D(L)',
#  ' D(CR)',
#  ' M(CR)',
#  ' M(CLR)',
#  ' AM(CR)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' D(CL)',
#  ' FW',
#  ' AM(CR)',
#  ' M(CLR)',
#  ' D(L)',
#  ' DMC',
#  ' GK',
#  ' D(LR)',
#  ' AM(CR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' GK',
#  ' M(C)',
#  ' FW',
#  ' DMC',
#  ' D(CR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' M(CL)',
#  ' D(L)',
#  ' M(C)',
#  ' D(CL)',
#  ' D(L)',
#  ' AM(C)',
#  ' D(L)',
#  ' FW',
#  ' AM(CL)',
#  ' D(CR)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' DMC',
#  ' M(C)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' D(LR)',
#  ' GK',
#  ' FW',
#  ' AM(CLR)',
#  ' D(R)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' FW',
#  ' D(L)',
#  ' D(C)',
#  ' AM(CR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' M(C)',
#  ' M(CLR)',
#  ' AM(CL)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' GK',
#  ' D(C)',
#  ' D(C)',
#  ' M(C)',
#  ' D(L)',
#  ' D(C)',
#  ' D(C)',
#  ' FW',
#  ' M(C)',
#  ' D(CR)',
#  ' M(LR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(CL)',
#  ' M(CR)',
#  ' D(CR)',
#  ' D(C)',
#  ' D(CR)',
#  ' AM(CL)',
#  ' M(CR)',
#  ' GK',
#  ' M(C)',
#  ' AM(LR)',
#  ' AM(CLR)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(R)',
#  ' D(L)',
#  ' D(CR)',
#  ' D(C)',
#  ' GK',
#  ' FW',
#  ' M(LR)',
#  ' M(CLR)',
#  ' D(CR)',
#  ' D(CL)',
#  ' D(C)',
#  ' AM(CR)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' AM(CLR)',
#  ' D(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' GK',
#  ' DMC',
#  ' D(R)',
#  ' D(CR)',
#  ' AM(CL)',
#  ' AM(R)',
#  ' FW',
#  ' M(LR)',
#  ' FW',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' D(R)',
#  ' GK',
#  ' M(CLR)',
#  ' D(C)',
#  ' D(CL)',
#  ' DMC',
#  ' M(CLR)',
#  ' D(L)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' DMC',
#  ' D(C)',
#  ' D(LR)',
#  ' D(L)',
#  ' M(CLR)',
#  ' AM(R)',
#  ' D(CL)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' D(C)',
#  ' GK',
#  ' AM(CLR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' GK',
#  ' AM(CLR)',
#  ' D(R)',
#  ' D(CR)',
#  ' M(C)',
#  ' D(L)',
#  ' D(CR)',
#  ' M(C)',
#  ' D(R)',
#  ' D(C)',
#  ' M(LR)',
#  ' D(LR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(CR)',
#  ' M(C)',
#  ' DMC',
#  ' D(CR)',
#  ' D(C)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' D(R)',
#  ' FW',
#  ' D(CR)',
#  ' GK',
#  ' D(C)',
#  ' D(R)',
#  ' D(C)',
#  ' D(CL)',
#  ' D(C)',
#  ' AM(CR)',
#  ' M(C)',
#  ' GK',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' GK',
#  ' AM(CR)',
#  ' D(R)',
#  ' AM(LR)',
#  ' DMC',
#  ' M(C)',
#  ' D(R)',
#  ' D(L)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' GK',
#  ' FW',
#  ' M(CLR)',
#  ' FW',
#  ' M(CR)',
#  ' D(C)',
#  ' D(L)',
#  ' D(CL)',
#  ' AM(CLR)',
#  ' FW',
#  ' M(CR)',
#  ' D(LR)',
#  ' D(L)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(C)',
#  ' GK',
#  ' D(C)',
#  ' D(L)',
#  ' AM(R)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(C)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' AM(CLR)',
#  ' M(CR)',
#  ' M(C)',
#  ' M(CL)',
#  ' D(L)',
#  ' GK',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' M(LR)',
#  ' M(CR)',
#  ' AM(C)',
#  ' AM(CR)',
#  ' M(CL)',
#  ' D(R)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' D(CL)',
#  ' M(CL)',
#  ' AM(LR)',
#  ' GK',
#  ' FW',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' D(R)',
#  ' AM(LR)',
#  ' D(C)',
#  ' FW',
#  ' M(CLR)',
#  ' AM(CLR)',
#  ' D(CL)',
#  ' D(C)',
#  ' GK',
#  ' D(C)',
#  ' D(C)',
#  ' D(L)',
#  ' D(CR)',
#  ' M(CR)',
#  ' M(CLR)',
#  ' AM(CR)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' D(CL)',
#  ' FW',
#  ' AM(CR)',
#  ' M(CLR)',
#  ' D(L)',
#  ' DMC',
#  ' GK',
#  ' D(LR)',
#  ' AM(CR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' GK',
#  ' M(C)',
#  ' FW',
#  ' DMC',
#  ' D(CR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' M(CL)',
#  ' D(L)',
#  ' M(C)',
#  ' D(CL)',
#  ' D(L)',
#  ' AM(C)',
#  ' D(L)',
#  ' FW',
#  ' AM(CL)',
#  ' D(CR)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' DMC',
#  ' M(C)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' D(LR)',
#  ' GK',
#  ' FW',
#  ' AM(CLR)',
#  ' D(R)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' FW',
#  ' D(L)',
#  ' D(C)',
#  ' AM(CR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' M(C)',
#  ' M(CLR)',
#  ' AM(CL)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' GK',
#  ' D(C)',
#  ' D(C)',
#  ' M(C)',
#  ' D(L)',
#  ' D(C)',
#  ' D(C)',
#  ' FW',
#  ' D(C)',
#  ' D(CLR)',
#  ' AM(CLR)',
#  ' AM(LR)',
#  ' AM(CL)',
#  ' M(CLR)',
#  ' FW',
#  ' D(L)',
#  ' AM(CLR)',
#  ' M(C)',
#  ' M(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' M(CR)',
#  ' M(LR)',
#  ' D(CL)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' GK',
#  ' D(CL)',
#  ' FW',
#  ' M(C)',
#  ' D(CR)',
#  ' M(LR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(CL)',
#  ' M(CR)',
#  ' D(CR)',
#  ' D(C)',
#  ' D(CR)',
#  ' AM(CL)',
#  ' M(CR)',
#  ' GK',
#  ' M(C)',
#  ' AM(LR)',
#  ' AM(CLR)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(R)',
#  ' D(L)',
#  ' D(CR)',
#  ' D(C)',
#  ' GK',
#  ' FW',
#  ' M(LR)',
#  ' M(CLR)',
#  ' D(CR)',
#  ' D(CL)',
#  ' D(C)',
#  ' AM(CR)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' AM(CLR)',
#  ' D(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' GK',
#  ' DMC',
#  ' D(R)',
#  ' D(CR)',
#  ' AM(CL)',
#  ' AM(R)',
#  ' FW',
#  ' M(LR)',
#  ' FW',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' D(R)',
#  ' GK',
#  ' M(CLR)',
#  ' D(C)',
#  ' D(CL)',
#  ' DMC',
#  ' M(CLR)',
#  ' D(L)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' DMC',
#  ' D(C)',
#  ' D(LR)',
#  ' D(L)',
#  ' M(CLR)',
#  ' AM(R)',
#  ' D(CL)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' D(C)',
#  ' GK',
#  ' AM(CLR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' GK',
#  ' AM(CLR)',
#  ' D(R)',
#  ' D(CR)',
#  ' M(C)',
#  ' D(L)',
#  ' D(CR)',
#  ' M(C)',
#  ' D(R)',
#  ' D(C)',
#  ' M(LR)',
#  ' D(LR)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(CR)',
#  ' M(C)',
#  ' DMC',
#  ' D(CR)',
#  ' D(C)',
#  ' D(CL)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' D(R)',
#  ' FW',
#  ' D(CR)',
#  ' GK',
#  ' D(C)',
#  ' D(R)',
#  ' D(C)',
#  ' D(CL)',
#  ' D(C)',
#  ' AM(CR)',
#  ' M(C)',
#  ' GK',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' M(CLR)',
#  ' D(C)',
#  ' GK',
#  ' AM(CR)',
#  ' D(R)',
#  ' AM(LR)',
#  ' DMC',
#  ' M(C)',
#  ' D(R)',
#  ' D(L)',
#  ' D(C)',
#  ' AM(CLR)',
#  ' GK',
#  ' FW',
#  ' M(CLR)',
#  ' FW',
#  ' M(CR)',
#  ' D(C)',
#  ' D(L)',
#  ' D(CL)',
#  ' AM(CLR)',
#  ' FW',
#  ' M(CR)',
#  ' D(LR)',
#  ' D(L)',
#  ' D(C)',
#  ' M(CLR)',
#  ' D(C)',
#  ' GK',
#  ' D(C)',
#  ' D(L)',
#  ' AM(R)',
#  ' AM(CLR)',
#  ' M(CLR)',
#  ' M(C)',
#  ' M(CLR)',
#  ' M(CLR)',
#  ' D(CLR)',
#  ' AM(CLR)',
#  ' M(CR)',
#  ' M(C)',
#  ' M(CL)',
#  ' D(L)',
#  ' GK',
#  ' D(C)',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' M(LR)',
#  ' M(CR)',
#  ' AM(C)',
#  ' AM(CR)',
#  ' M(CL)',
#  ' D(R)',
#  ' AM(CLR)',
#  ' D(CR)',
#  ' D(CL)',
#  ' M(CL)',
#  ' AM(LR)',
#  ' GK',
#  ' FW',
#  ' AM(CLR)',
#  ' D(C)',
#  ' D(C)',
#  ' D(R)',
#  ' AM(LR)',
#  ...]

# %%
# 공백 삭제

for i in range(len(tmp_li)):
    tmp_li[i] = tmp_li[i].replace(' ', '')
tmp_li
# Out:
# ['FW',
#  'M(C)',
#  'D(CR)',
#  'M(LR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'D(C)',
#  'AM(CLR)',
#  'D(CL)',
#  'M(CR)',
#  'D(CR)',
#  'D(C)',
#  'D(CR)',
#  'AM(CL)',
#  'M(CR)',
#  'GK',
#  'M(C)',
#  'AM(LR)',
#  'AM(CLR)',
#  'AM(CLR)',
#  'D(C)',
#  'D(R)',
#  'D(L)',
#  'D(CR)',
#  'D(C)',
#  'GK',
#  'FW',
#  'M(LR)',
#  'M(CLR)',
#  'D(CR)',
#  'D(CL)',
#  'D(C)',
#  'AM(CR)',
#  'D(C)',
#  'AM(CLR)',
#  'M(CLR)',
#  'AM(CLR)',
#  'D(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'GK',
#  'DMC',
#  'D(R)',
#  'D(CR)',
#  'AM(CL)',
#  'AM(R)',
#  'FW',
#  'M(LR)',
#  'FW',
#  'AM(CLR)',
#  'D(CR)',
#  'D(R)',
#  'GK',
#  'M(CLR)',
#  'D(C)',
#  'D(CL)',
#  'DMC',
#  'M(CLR)',
#  'D(L)',
#  'AM(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'DMC',
#  'D(C)',
#  'D(LR)',
#  'D(L)',
#  'M(CLR)',
#  'AM(R)',
#  'D(CL)',
#  'D(CL)',
#  'M(CLR)',
#  'D(CLR)',
#  'D(C)',
#  'GK',
#  'AM(CLR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(CLR)',
#  'GK',
#  'AM(CLR)',
#  'D(R)',
#  'D(CR)',
#  'M(C)',
#  'D(L)',
#  'D(CR)',
#  'M(C)',
#  'D(R)',
#  'D(C)',
#  'M(LR)',
#  'D(LR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(CR)',
#  'M(C)',
#  'DMC',
#  'D(CR)',
#  'D(C)',
#  'D(CL)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(C)',
#  'D(R)',
#  'FW',
#  'D(CR)',
#  'GK',
#  'D(C)',
#  'D(R)',
#  'D(C)',
#  'D(CL)',
#  'D(C)',
#  'AM(CR)',
#  'M(C)',
#  'GK',
#  'AM(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'D(C)',
#  'GK',
#  'AM(CR)',
#  'D(R)',
#  'AM(LR)',
#  'DMC',
#  'M(C)',
#  'D(R)',
#  'D(L)',
#  'D(C)',
#  'AM(CLR)',
#  'GK',
#  'FW',
#  'M(CLR)',
#  'FW',
#  'M(CR)',
#  'D(C)',
#  'D(L)',
#  'D(CL)',
#  'AM(CLR)',
#  'FW',
#  'M(CR)',
#  'D(LR)',
#  'D(L)',
#  'D(C)',
#  'M(CLR)',
#  'D(C)',
#  'GK',
#  'D(C)',
#  'D(L)',
#  'AM(R)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(C)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(CLR)',
#  'AM(CLR)',
#  'M(CR)',
#  'M(C)',
#  'M(CL)',
#  'D(L)',
#  'GK',
#  'D(C)',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'M(LR)',
#  'M(CR)',
#  'AM(C)',
#  'AM(CR)',
#  'M(CL)',
#  'D(R)',
#  'AM(CLR)',
#  'D(CR)',
#  'D(CL)',
#  'M(CL)',
#  'AM(LR)',
#  'GK',
#  'FW',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'D(R)',
#  'AM(LR)',
#  'D(C)',
#  'FW',
#  'M(CLR)',
#  'AM(CLR)',
#  'D(CL)',
#  'D(C)',
#  'GK',
#  'D(C)',
#  'D(C)',
#  'D(L)',
#  'D(CR)',
#  'M(CR)',
#  'M(CLR)',
#  'AM(CR)',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'M(CLR)',
#  'D(CLR)',
#  'D(CL)',
#  'FW',
#  'AM(CR)',
#  'M(CLR)',
#  'D(L)',
#  'DMC',
#  'GK',
#  'D(LR)',
#  'AM(CR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'GK',
#  'M(C)',
#  'FW',
#  'DMC',
#  'D(CR)',
#  'M(CLR)',
#  'D(C)',
#  'M(CLR)',
#  'D(CLR)',
#  'M(CL)',
#  'D(L)',
#  'M(C)',
#  'D(CL)',
#  'D(L)',
#  'AM(C)',
#  'D(L)',
#  'FW',
#  'AM(CL)',
#  'D(CR)',
#  'AM(CLR)',
#  'D(CR)',
#  'DMC',
#  'M(C)',
#  'D(CL)',
#  'M(CLR)',
#  'D(LR)',
#  'GK',
#  'FW',
#  'AM(CLR)',
#  'D(R)',
#  'D(C)',
#  'AM(CLR)',
#  'D(C)',
#  'FW',
#  'D(L)',
#  'D(C)',
#  'AM(CR)',
#  'M(CLR)',
#  'D(C)',
#  'M(C)',
#  'M(CLR)',
#  'AM(CL)',
#  'D(C)',
#  'AM(CLR)',
#  'GK',
#  'D(C)',
#  'D(C)',
#  'M(C)',
#  'D(L)',
#  'D(C)',
#  'D(C)',
#  'FW',
#  'D(C)',
#  'D(CLR)',
#  'AM(CLR)',
#  'AM(LR)',
#  'AM(CL)',
#  'M(CLR)',
#  'FW',
#  'M(C)',
#  'D(CR)',
#  'M(LR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'D(C)',
#  'AM(CLR)',
#  'D(CL)',
#  'M(CR)',
#  'D(CR)',
#  'D(C)',
#  'D(CR)',
#  'AM(CL)',
#  'M(CR)',
#  'GK',
#  'M(C)',
#  'AM(LR)',
#  'AM(CLR)',
#  'AM(CLR)',
#  'D(C)',
#  'D(R)',
#  'D(L)',
#  'D(CR)',
#  'D(C)',
#  'GK',
#  'FW',
#  'M(LR)',
#  'M(CLR)',
#  'D(CR)',
#  'D(CL)',
#  'D(C)',
#  'AM(CR)',
#  'D(C)',
#  'AM(CLR)',
#  'M(CLR)',
#  'AM(CLR)',
#  'D(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'GK',
#  'DMC',
#  'D(R)',
#  'D(CR)',
#  'AM(CL)',
#  'AM(R)',
#  'FW',
#  'M(LR)',
#  'FW',
#  'AM(CLR)',
#  'D(CR)',
#  'D(R)',
#  'GK',
#  'M(CLR)',
#  'D(C)',
#  'D(CL)',
#  'DMC',
#  'M(CLR)',
#  'D(L)',
#  'AM(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'DMC',
#  'D(C)',
#  'D(LR)',
#  'D(L)',
#  'M(CLR)',
#  'AM(R)',
#  'D(CL)',
#  'D(CL)',
#  'M(CLR)',
#  'D(CLR)',
#  'D(C)',
#  'GK',
#  'AM(CLR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(CLR)',
#  'GK',
#  'AM(CLR)',
#  'D(R)',
#  'D(CR)',
#  'M(C)',
#  'D(L)',
#  'D(CR)',
#  'M(C)',
#  'D(R)',
#  'D(C)',
#  'M(LR)',
#  'D(LR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(CR)',
#  'M(C)',
#  'DMC',
#  'D(CR)',
#  'D(C)',
#  'D(CL)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(C)',
#  'D(R)',
#  'FW',
#  'D(CR)',
#  'GK',
#  'D(C)',
#  'D(R)',
#  'D(C)',
#  'D(CL)',
#  'D(C)',
#  'AM(CR)',
#  'M(C)',
#  'GK',
#  'AM(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'D(C)',
#  'GK',
#  'AM(CR)',
#  'D(R)',
#  'AM(LR)',
#  'DMC',
#  'M(C)',
#  'D(R)',
#  'D(L)',
#  'D(C)',
#  'AM(CLR)',
#  'GK',
#  'FW',
#  'M(CLR)',
#  'FW',
#  'M(CR)',
#  'D(C)',
#  'D(L)',
#  'D(CL)',
#  'AM(CLR)',
#  'FW',
#  'M(CR)',
#  'D(LR)',
#  'D(L)',
#  'D(C)',
#  'M(CLR)',
#  'D(C)',
#  'GK',
#  'D(C)',
#  'D(L)',
#  'AM(R)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(C)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(CLR)',
#  'AM(CLR)',
#  'M(CR)',
#  'M(C)',
#  'M(CL)',
#  'D(L)',
#  'GK',
#  'D(C)',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'M(LR)',
#  'M(CR)',
#  'AM(C)',
#  'AM(CR)',
#  'M(CL)',
#  'D(R)',
#  'AM(CLR)',
#  'D(CR)',
#  'D(CL)',
#  'M(CL)',
#  'AM(LR)',
#  'GK',
#  'FW',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'D(R)',
#  'AM(LR)',
#  'D(C)',
#  'FW',
#  'M(CLR)',
#  'AM(CLR)',
#  'D(CL)',
#  'D(C)',
#  'GK',
#  'D(C)',
#  'D(C)',
#  'D(L)',
#  'D(CR)',
#  'M(CR)',
#  'M(CLR)',
#  'AM(CR)',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'M(CLR)',
#  'D(CLR)',
#  'D(CL)',
#  'FW',
#  'AM(CR)',
#  'M(CLR)',
#  'D(L)',
#  'DMC',
#  'GK',
#  'D(LR)',
#  'AM(CR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'GK',
#  'M(C)',
#  'FW',
#  'DMC',
#  'D(CR)',
#  'M(CLR)',
#  'D(C)',
#  'M(CLR)',
#  'D(CLR)',
#  'M(CL)',
#  'D(L)',
#  'M(C)',
#  'D(CL)',
#  'D(L)',
#  'AM(C)',
#  'D(L)',
#  'FW',
#  'AM(CL)',
#  'D(CR)',
#  'AM(CLR)',
#  'D(CR)',
#  'DMC',
#  'M(C)',
#  'D(CL)',
#  'M(CLR)',
#  'D(LR)',
#  'GK',
#  'FW',
#  'AM(CLR)',
#  'D(R)',
#  'D(C)',
#  'AM(CLR)',
#  'D(C)',
#  'FW',
#  'D(L)',
#  'D(C)',
#  'AM(CR)',
#  'M(CLR)',
#  'D(C)',
#  'M(C)',
#  'M(CLR)',
#  'AM(CL)',
#  'D(C)',
#  'AM(CLR)',
#  'GK',
#  'D(C)',
#  'D(C)',
#  'M(C)',
#  'D(L)',
#  'D(C)',
#  'D(C)',
#  'FW',
#  'M(C)',
#  'D(CR)',
#  'M(LR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'D(C)',
#  'AM(CLR)',
#  'D(CL)',
#  'M(CR)',
#  'D(CR)',
#  'D(C)',
#  'D(CR)',
#  'AM(CL)',
#  'M(CR)',
#  'GK',
#  'M(C)',
#  'AM(LR)',
#  'AM(CLR)',
#  'AM(CLR)',
#  'D(C)',
#  'D(R)',
#  'D(L)',
#  'D(CR)',
#  'D(C)',
#  'GK',
#  'FW',
#  'M(LR)',
#  'M(CLR)',
#  'D(CR)',
#  'D(CL)',
#  'D(C)',
#  'AM(CR)',
#  'D(C)',
#  'AM(CLR)',
#  'M(CLR)',
#  'AM(CLR)',
#  'D(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'GK',
#  'DMC',
#  'D(R)',
#  'D(CR)',
#  'AM(CL)',
#  'AM(R)',
#  'FW',
#  'M(LR)',
#  'FW',
#  'AM(CLR)',
#  'D(CR)',
#  'D(R)',
#  'GK',
#  'M(CLR)',
#  'D(C)',
#  'D(CL)',
#  'DMC',
#  'M(CLR)',
#  'D(L)',
#  'AM(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'DMC',
#  'D(C)',
#  'D(LR)',
#  'D(L)',
#  'M(CLR)',
#  'AM(R)',
#  'D(CL)',
#  'D(CL)',
#  'M(CLR)',
#  'D(CLR)',
#  'D(C)',
#  'GK',
#  'AM(CLR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(CLR)',
#  'GK',
#  'AM(CLR)',
#  'D(R)',
#  'D(CR)',
#  'M(C)',
#  'D(L)',
#  'D(CR)',
#  'M(C)',
#  'D(R)',
#  'D(C)',
#  'M(LR)',
#  'D(LR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(CR)',
#  'M(C)',
#  'DMC',
#  'D(CR)',
#  'D(C)',
#  'D(CL)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(C)',
#  'D(R)',
#  'FW',
#  'D(CR)',
#  'GK',
#  'D(C)',
#  'D(R)',
#  'D(C)',
#  'D(CL)',
#  'D(C)',
#  'AM(CR)',
#  'M(C)',
#  'GK',
#  'AM(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'D(C)',
#  'GK',
#  'AM(CR)',
#  'D(R)',
#  'AM(LR)',
#  'DMC',
#  'M(C)',
#  'D(R)',
#  'D(L)',
#  'D(C)',
#  'AM(CLR)',
#  'GK',
#  'FW',
#  'M(CLR)',
#  'FW',
#  'M(CR)',
#  'D(C)',
#  'D(L)',
#  'D(CL)',
#  'AM(CLR)',
#  'FW',
#  'M(CR)',
#  'D(LR)',
#  'D(L)',
#  'D(C)',
#  'M(CLR)',
#  'D(C)',
#  'GK',
#  'D(C)',
#  'D(L)',
#  'AM(R)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(C)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(CLR)',
#  'AM(CLR)',
#  'M(CR)',
#  'M(C)',
#  'M(CL)',
#  'D(L)',
#  'GK',
#  'D(C)',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'M(LR)',
#  'M(CR)',
#  'AM(C)',
#  'AM(CR)',
#  'M(CL)',
#  'D(R)',
#  'AM(CLR)',
#  'D(CR)',
#  'D(CL)',
#  'M(CL)',
#  'AM(LR)',
#  'GK',
#  'FW',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'D(R)',
#  'AM(LR)',
#  'D(C)',
#  'FW',
#  'M(CLR)',
#  'AM(CLR)',
#  'D(CL)',
#  'D(C)',
#  'GK',
#  'D(C)',
#  'D(C)',
#  'D(L)',
#  'D(CR)',
#  'M(CR)',
#  'M(CLR)',
#  'AM(CR)',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'M(CLR)',
#  'D(CLR)',
#  'D(CL)',
#  'FW',
#  'AM(CR)',
#  'M(CLR)',
#  'D(L)',
#  'DMC',
#  'GK',
#  'D(LR)',
#  'AM(CR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'GK',
#  'M(C)',
#  'FW',
#  'DMC',
#  'D(CR)',
#  'M(CLR)',
#  'D(C)',
#  'M(CLR)',
#  'D(CLR)',
#  'M(CL)',
#  'D(L)',
#  'M(C)',
#  'D(CL)',
#  'D(L)',
#  'AM(C)',
#  'D(L)',
#  'FW',
#  'AM(CL)',
#  'D(CR)',
#  'AM(CLR)',
#  'D(CR)',
#  'DMC',
#  'M(C)',
#  'D(CL)',
#  'M(CLR)',
#  'D(LR)',
#  'GK',
#  'FW',
#  'AM(CLR)',
#  'D(R)',
#  'D(C)',
#  'AM(CLR)',
#  'D(C)',
#  'FW',
#  'D(L)',
#  'D(C)',
#  'AM(CR)',
#  'M(CLR)',
#  'D(C)',
#  'M(C)',
#  'M(CLR)',
#  'AM(CL)',
#  'D(C)',
#  'AM(CLR)',
#  'GK',
#  'D(C)',
#  'D(C)',
#  'M(C)',
#  'D(L)',
#  'D(C)',
#  'D(C)',
#  'FW',
#  'D(C)',
#  'D(CLR)',
#  'AM(CLR)',
#  'AM(LR)',
#  'AM(CL)',
#  'M(CLR)',
#  'FW',
#  'D(L)',
#  'AM(CLR)',
#  'M(C)',
#  'M(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'D(CLR)',
#  'M(CR)',
#  'M(LR)',
#  'D(CL)',
#  'D(CR)',
#  'M(CLR)',
#  'GK',
#  'D(CL)',
#  'FW',
#  'M(C)',
#  'D(CR)',
#  'M(LR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'D(C)',
#  'AM(CLR)',
#  'D(CL)',
#  'M(CR)',
#  'D(CR)',
#  'D(C)',
#  'D(CR)',
#  'AM(CL)',
#  'M(CR)',
#  'GK',
#  'M(C)',
#  'AM(LR)',
#  'AM(CLR)',
#  'AM(CLR)',
#  'D(C)',
#  'D(R)',
#  'D(L)',
#  'D(CR)',
#  'D(C)',
#  'GK',
#  'FW',
#  'M(LR)',
#  'M(CLR)',
#  'D(CR)',
#  'D(CL)',
#  'D(C)',
#  'AM(CR)',
#  'D(C)',
#  'AM(CLR)',
#  'M(CLR)',
#  'AM(CLR)',
#  'D(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'GK',
#  'DMC',
#  'D(R)',
#  'D(CR)',
#  'AM(CL)',
#  'AM(R)',
#  'FW',
#  'M(LR)',
#  'FW',
#  'AM(CLR)',
#  'D(CR)',
#  'D(R)',
#  'GK',
#  'M(CLR)',
#  'D(C)',
#  'D(CL)',
#  'DMC',
#  'M(CLR)',
#  'D(L)',
#  'AM(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'DMC',
#  'D(C)',
#  'D(LR)',
#  'D(L)',
#  'M(CLR)',
#  'AM(R)',
#  'D(CL)',
#  'D(CL)',
#  'M(CLR)',
#  'D(CLR)',
#  'D(C)',
#  'GK',
#  'AM(CLR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(CLR)',
#  'GK',
#  'AM(CLR)',
#  'D(R)',
#  'D(CR)',
#  'M(C)',
#  'D(L)',
#  'D(CR)',
#  'M(C)',
#  'D(R)',
#  'D(C)',
#  'M(LR)',
#  'D(LR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(CR)',
#  'M(C)',
#  'DMC',
#  'D(CR)',
#  'D(C)',
#  'D(CL)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(C)',
#  'D(R)',
#  'FW',
#  'D(CR)',
#  'GK',
#  'D(C)',
#  'D(R)',
#  'D(C)',
#  'D(CL)',
#  'D(C)',
#  'AM(CR)',
#  'M(C)',
#  'GK',
#  'AM(CLR)',
#  'D(CR)',
#  'M(CLR)',
#  'D(C)',
#  'GK',
#  'AM(CR)',
#  'D(R)',
#  'AM(LR)',
#  'DMC',
#  'M(C)',
#  'D(R)',
#  'D(L)',
#  'D(C)',
#  'AM(CLR)',
#  'GK',
#  'FW',
#  'M(CLR)',
#  'FW',
#  'M(CR)',
#  'D(C)',
#  'D(L)',
#  'D(CL)',
#  'AM(CLR)',
#  'FW',
#  'M(CR)',
#  'D(LR)',
#  'D(L)',
#  'D(C)',
#  'M(CLR)',
#  'D(C)',
#  'GK',
#  'D(C)',
#  'D(L)',
#  'AM(R)',
#  'AM(CLR)',
#  'M(CLR)',
#  'M(C)',
#  'M(CLR)',
#  'M(CLR)',
#  'D(CLR)',
#  'AM(CLR)',
#  'M(CR)',
#  'M(C)',
#  'M(CL)',
#  'D(L)',
#  'GK',
#  'D(C)',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'M(LR)',
#  'M(CR)',
#  'AM(C)',
#  'AM(CR)',
#  'M(CL)',
#  'D(R)',
#  'AM(CLR)',
#  'D(CR)',
#  'D(CL)',
#  'M(CL)',
#  'AM(LR)',
#  'GK',
#  'FW',
#  'AM(CLR)',
#  'D(C)',
#  'D(C)',
#  'D(R)',
#  'AM(LR)',
#  ...]

# %%
tmp = pd.DataFrame(tmp_li, columns=['Position'])
tmp
# Out:
#      Position
# 0          FW
# 1        M(C)
# 2       D(CR)
# 3       M(LR)
# 4     AM(CLR)
# ...       ...
# 1391    D(CR)
# 1392   M(CLR)
# 1393       GK
# 1394    D(CL)
# 1395  AM(CLR)
#
# [1396 rows x 1 columns]

# %%
# 원래 데이터에 적용

BL_5_seasons_data['Position'] = tmp

# %%
BL_5_seasons_data['Position'].unique()
# Out:
# array(['FW', 'M(C)', 'D(CR)', 'M(LR)', 'AM(CLR)', 'M(CLR)', 'D(C)',
#        'D(CL)', 'M(CR)', 'AM(CL)', 'GK', 'AM(LR)', 'D(R)', 'D(L)',
#        'AM(CR)', 'D(CLR)', 'DMC', 'AM(R)', 'D(LR)', 'M(CL)', 'AM(C)'],
#       dtype=object)

# %% [markdown]
# # Apps 전처리

# %%
# Apps -> 출전횟수
# 교체 출전의 경우 괄호에 있다.
# 그냥 합쳐준다.
apps_df = BL_5_seasons_data['Apps']
apps_df.head()
#  '7(19)',
#  '9(22)',
#  '24(2)',
#  '25(1)',
#  '23(9)',
#  '23(5)',
#  '21(1)',
#  '23(5)',
#  '26(1)',
#  '32',
#  '20(6)',
#  '28',
#  '8(12)',
#  '20(10)',
#  '16(7)',
#  '18(2)',
#  '5(18)',
#  '7(11)',
#  '31(1)',
#  '30(2)',
#  '16(2)',
#  '25(3)',
#  '21(3)',
#  '13(6)',
#  '13(20)',
#  '33',
#  '23(6)',
#  '17(3)',
#  '14(5)',
#  '26(2)',
#  '17(10)',
#  '18(8)',
#  '19(7)',
#  '7(14)',
#  '29(1)',
#  '9(16)',
#  '28(3)',
#  '32',
#  '28(3)',
#  '26(3)',
#  '26',
#  '28(3)',
#  '32',
#  '23(9)',
#  '25(2)',
#  '12(6)',
#  '21(5)',
#  '10(7)',
#  '9(14)',
#  '15(2)',
#  '9(17)',
#  '4(14)',
#  '31(1)',
#  '20',
#  '24(6)',
#  '20(2)',
#  '30',
#  '31(1)',
#  '26(5)',
#  '21',
#  '22(8)',
#  '29(2)',
#  '25(5)',
#  '16(1)',
#  '20(11)',
#  '10(19)',
#  '13(13)',
#  '6(22)',
#  '1(17)',
#  '30',
#  '32',
#  '30',
#  '20(3)',
#  '26(6)',
#  '22(6)',
#  '16(3)',
#  '17(2)',
#  '14(11)',
#  '14(9)',
#  '19(2)',
#  '18(10)',
#  '20(7)',
#  '29(2)',
#  '6(11)',
#  '11(13)',
#  '31',
#  '28',
#  '19(2)',
#  '33',
#  '21(4)',
#  '23(1)',
#  '29',
#  '26(3)',
#  '22(6)',
#  '11(9)',
#  '30',
#  '11(8)',
#  '11(10)',
#  '34',
#  '29',
#  ...]

# %%
# ()안에 있는 숫자를 그냥 더해줌
# Apps값을 int형으로 변환

for i in range(1396):
    if '(' in tmp_li[i]:
        tmp_li[i] = tmp_li[i].split('(')
        tmp_li[i] = [tmp_li[i][0], tmp_li[i][1].replace(')', '')]
        tmp_li[i] = int(tmp_li[i][0]) + int(tmp_li[i][1])
    else:
        tmp_li[i] = int(tmp_li[i])
    
tmp_df = pd.DataFrame(tmp_li, columns=['Apps'])
tmp_df
# Out:
#       Apps
# 0       33
# 1       30
# 2       34
# 3       21
# 4       20
# ...    ...
# 1391    28
# 1392    31
# 1393    29
# 1394    27
# 1395    20
#
# [1396 rows x 1 columns]

# %%
BL_5_seasons_data['Apps'] = tmp_df
BL_5_seasons_data[['Apps']]
# Out:
#      Apps
# 0      33
# 1      30
# 2      34
# 3      21
# 4      20
# ..    ...
# 281    24
# 282    22
# 283    33
# 284    19
# 285    32
#
# [1396 rows x 1 columns]

# %% [markdown]
# # 포지션 구분
# ## 전처리 추가 필요 -> FW, AM, M, DM, D, GK

# %%
position_li = BL_5_seasons_data['Position'].unique().tolist()
position_li
# Out:
# ['FW',
#  'M(C)',
#  'D(CR)',
#  'M(LR)',
#  'AM(CLR)',
#  'M(CLR)',
#  'D(C)',
#  'D(CL)',
#  'M(CR)',
#  'AM(CL)',
#  'GK',
#  'AM(LR)',
#  'D(R)',
#  'D(L)',
#  'AM(CR)',
#  'D(CLR)',
#  'DMC',
#  'AM(R)',
#  'D(LR)',
#  'M(CL)',
#  'AM(C)']

# %%
tmp_li = BL_5_seasons_data['Position'].tolist()

for i in range(BL_5_seasons_data.shape[0]):
    pos_tmp = tmp_li[i]
    if '(' in pos_tmp:
        pos_tmp_li = pos_tmp.split('(')
        tmp_li[i] = pos_tmp_li[0]
        
    if tmp_li[i] == 'Forward':
        tmp_li[i] = 'FW'
        
    elif tmp_li[i] == 'DMC':
        tmp_li[i] = 'DM'
        
    elif tmp_li[i] == 'Midfielder':
        tmp_li[i] = 'M'

# %%
# 원본 데이터에 적용

BL_5_seasons_data['Position'] = pd.DataFrame(tmp_li, columns=['Position'])

# %%
BL_5_seasons_data['Position'].unique()
# Out:
# array(['FW', 'M', 'D', 'AM', 'GK', 'DM'], dtype=object)

# %% [markdown]
# # 결측치 처리

# %%
BL_5_seasons_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1396 entries, 0 to 285
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        1396 non-null   object
#  1   Team        1396 non-null   object
#  2   Age         1396 non-null   int64
#  3   Position    1396 non-null   object
#  4   Apps        1396 non-null   int64
#  5   Mins        1396 non-null   int64
#  6   Goals       1396 non-null   object
#  7   Assists     1396 non-null   object
#  8   Yellow      1396 non-null   object
#  9   Red         1396 non-null   object
#  10  SpG         1396 non-null   object
#  11  PS          1396 non-null   float64
#  12  Aerialswon  1396 non-null   object
#  13  MotM        1396 non-null   object
#  14  Rating      1396 non-null   float64
#  15  Tackles     1396 non-null   object
#  16  Inter       1396 non-null   object
#  17  Fouls       1396 non-null   object
#  18  Offsides    1396 non-null   object
#  19  Clear       1396 non-null   object
#  20  Drb_def     1396 non-null   object
#  21  Blocks      1396 non-null   object
#  22  OwnG        1396 non-null   object
#  23  Drb_off     1396 non-null   object
#  24  Fouled      1396 non-null   object
#  25  Off         1396 non-null   object
#  26  Disp        1396 non-null   object
#  27  UnsTch      1396 non-null   object
#  28  AvgP        1396 non-null   float64
#  29  PSp         1396 non-null   float64
#  30  Crosses     1396 non-null   object
#  31  LonB        1396 non-null   object
#  32  ThrB        1396 non-null   object
#  33  Pts         1396 non-null   int64
# dtypes: float64(4), int64(4), object(26)
# memory usage: 381.7+ KB

# %%
# Apps

tmp = BL_5_seasons_data['Apps'].tolist()
for i in range(len(tmp)):
    tmp[i] = int(tmp[i])
    
BL_5_seasons_data['Apps'] = pd.DataFrame(tmp, columns=['Apps'])

# %%
# Goals

tmp = BL_5_seasons_data['Goals'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = int(tmp[i])
    
BL_5_seasons_data['Goals'] = pd.DataFrame(tmp, columns=['Goals'])

# %%
# Assists

tmp = BL_5_seasons_data['Assists'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = int(tmp[i])
    
BL_5_seasons_data['Assists'] = pd.DataFrame(tmp, columns=['Assists'])

# %%
# Yellow

tmp = BL_5_seasons_data['Yellow'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = int(tmp[i])
    
BL_5_seasons_data['Yellow'] = pd.DataFrame(tmp, columns=['Yellow'])

# %%
# Red

tmp = BL_5_seasons_data['Red'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = int(tmp[i])
    
BL_5_seasons_data['Red'] = pd.DataFrame(tmp, columns=['Red'])

# %%
# SpG

tmp = BL_5_seasons_data['SpG'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['SpG'] = pd.DataFrame(tmp, columns=['SpG'])

# %%
# Aerialswon

tmp = BL_5_seasons_data['Aerialswon'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Aerialswon'] = pd.DataFrame(tmp, columns=['Aerialswon'])

# %%
# MotM

tmp = BL_5_seasons_data['MotM'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = int(tmp[i])
    
BL_5_seasons_data['MotM'] = pd.DataFrame(tmp, columns=['MotM'])

# %%
# Tackles

tmp = BL_5_seasons_data['Tackles'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Tackles'] = pd.DataFrame(tmp, columns=['Tackles'])

# %%
# Inter 

tmp = BL_5_seasons_data['Inter'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Inter'] = pd.DataFrame(tmp, columns=['Inter'])

# %%
# Fouls

tmp = BL_5_seasons_data['Fouls'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Fouls'] = pd.DataFrame(tmp, columns=['Fouls'])

# %%
# Offsides

tmp = BL_5_seasons_data['Offsides'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Offsides'] = pd.DataFrame(tmp, columns=['Offsides'])

# %%
# Clear

tmp = BL_5_seasons_data['Clear'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Clear'] = pd.DataFrame(tmp, columns=['Clear'])

# %%
# Drb_def

tmp = BL_5_seasons_data['Drb_def'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Drb_def'] = pd.DataFrame(tmp, columns=['Drb_def'])

# %%
# Blocks

tmp = BL_5_seasons_data['Blocks'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Blocks'] = pd.DataFrame(tmp, columns=['Blocks'])

# %%
# OwnG

tmp = BL_5_seasons_data['OwnG'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = int(tmp[i])
    
BL_5_seasons_data['OwnG'] = pd.DataFrame(tmp, columns=['OwnG'])

# %%
# Drb_off

tmp = BL_5_seasons_data['Drb_off'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Drb_off'] = pd.DataFrame(tmp, columns=['Drb_off'])

# %%
# Fouled

tmp = BL_5_seasons_data['Fouled'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Fouled'] = pd.DataFrame(tmp, columns=['Fouled'])

# %%
# Off

tmp = BL_5_seasons_data['Off'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Off'] = pd.DataFrame(tmp, columns=['Off'])

# %%
# Disp

tmp = BL_5_seasons_data['Disp'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Disp'] = pd.DataFrame(tmp, columns=['Disp'])

# %%
# UnsTch

tmp = BL_5_seasons_data['UnsTch'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['UnsTch'] = pd.DataFrame(tmp, columns=['UnsTch'])

# %%
# Crosses

tmp = BL_5_seasons_data['Crosses'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['Crosses'] = pd.DataFrame(tmp, columns=['Crosses'])

# %%
# LonB

tmp = BL_5_seasons_data['LonB'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['LonB'] = pd.DataFrame(tmp, columns=['LonB'])

# %%
# ThrB

tmp = BL_5_seasons_data['ThrB'].tolist()
for i in range(len(tmp)):
    if tmp[i] == '-':
        tmp[i] = 0
    tmp[i] = float(tmp[i])
    
BL_5_seasons_data['ThrB'] = pd.DataFrame(tmp, columns=['ThrB'])

# %% [markdown]
# # 포지션별 dataframe 생성

# %%
FW_df = BL_5_seasons_data[BL_5_seasons_data['Position'] == 'FW']
print(FW_df.shape)
#FW_player_df.to_csv('BL_FW_Player.csv', encoding='utf-8-sig')
# Out:
# (82, 34)

# %%
AM_df = BL_5_seasons_data[BL_5_seasons_data['Position'] == 'AM']
AM_df.shape
#AM_player_df.to_csv('BL_AM_Player.csv', encoding='utf-8-sig')
# Out:
# (264, 34)

# %%
M_df = BL_5_seasons_data[BL_5_seasons_data['Position'] == 'M']
M_df.shape
#M_player_df.to_csv('BL_M_Player.csv', encoding='utf-8-sig')
# Out:
# (325, 34)

# %%
DM_df = BL_5_seasons_data[BL_5_seasons_data['Position'] == 'DM']
DM_df.shape
#DM_player_df.to_csv('BL_DM_Player.csv', encoding='utf-8-sig')
# Out:
# (40, 34)

# %%
D_df = BL_5_seasons_data[BL_5_seasons_data['Position'] == 'D']
D_df.shape
#D_player_df.to_csv('BL_D_Player.csv', encoding='utf-8-sig')
# Out:
# (593, 34)

# %%
GK_df = BL_5_seasons_data[BL_5_seasons_data['Position'] == 'GK']
GK_df.shape
#GK_player_df.to_csv('BL_GK_Player.csv', encoding='utf-8-sig')
# Out:
# (92, 34)

# %% [markdown]
# # FW 포지션 분석

# %%
FW_df.head()
# Out:
#                    Name                 Team  Age Position  Apps  Mins  Goals  \
# 0    Robert Lewandowski        Bayern Munich   35       FW    33  2959     22
# 26          Ádám Szalai           Hoffenheim   36       FW    30  1621      6
# 46     Sébastien Haller  Eintracht Frankfurt   29       FW    29  2181     15
# 48           Luka Jovic  Eintracht Frankfurt   26       FW    32  2249     17
# 103        Lucas Alario     Bayer Leverkusen   31       FW    27  1256      9
#
#      Assists  Yellow  Red  ...  Fouled  Off  Disp  UnsTch  AvgP   PSp  \
# 0          7       2    0  ...     1.4  0.9   1.5     1.5  22.1  77.5
# 26         3       3    0  ...     0.8  0.3   0.7     0.7  14.0  71.1
# 46         9       3    0  ...     1.5  0.7   1.7     1.7  27.0  63.5
# 48         5       1    0  ...     1.3  0.5   1.4     1.4  18.7  70.4
# 103        3       1    0  ...     0.9  0.5   0.9     0.9  15.0  75.5
#
#      Crosses  LonB  ThrB  Pts
# 0        0.0   0.6   0.2   78
# 26       0.0   0.4   0.0   51
# 46       0.0   0.4   0.1   54
# 48       0.1   0.9   0.1   54
# 103      0.0   0.3   0.0   58
#
# [5 rows x 34 columns]

# %%
FW_df.columns
# Out:
# Index(['Name', 'Team', 'Age', 'Position', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yellow', 'Red', 'SpG', 'PS', 'Aerialswon', 'MotM', 'Rating', 'Tackles',
#        'Inter', 'Fouls', 'Offsides', 'Clear', 'Drb_def', 'Blocks', 'OwnG',
#        'Drb_off', 'Fouled', 'Off', 'Disp', 'UnsTch', 'AvgP', 'PSp', 'Crosses',
#        'LonB', 'ThrB', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

FW_numeric_df = FW_df.select_dtypes(['int64', 'float64'])

# %%
FW_corr_matrix = FW_numeric_df.corr()
FW_corr_matrix
# Out:
# Clear       0.201949  0.201949  0.050397 -0.005759 -0.100240  0.151379
# Drb_def     0.305420  0.305420  0.082636 -0.000500  0.203861  0.105355
# Blocks     -0.136163 -0.136163  0.059606 -0.118297 -0.050145 -0.237510
# OwnG       -0.130505 -0.130505 -0.017474  0.021025 -0.195140  0.218542
# Drb_off     0.747182  0.747182 -0.042611  0.062462  0.541887  0.245709
# Fouled      0.632993  0.632993  0.100946  0.114156  0.322000  0.268281
# Off         0.521398  0.521398 -0.001495  0.065226  0.189794  0.106895
# Disp        1.000000  1.000000  0.022033  0.088469  0.474688  0.241893
# UnsTch      1.000000  1.000000  0.022033  0.088469  0.474688  0.241893
# AvgP        0.022033  0.022033  1.000000  0.629490 -0.087515 -0.072689
# PSp         0.088469  0.088469  0.629490  1.000000 -0.013000  0.257215
# Crosses     0.474688  0.474688 -0.087515 -0.013000  1.000000 -0.023128
# LonB        0.241893  0.241893 -0.072689  0.257215 -0.023128  1.000000
# ThrB        0.221542  0.221542 -0.133880  0.097434 -0.034526  0.496575
# Pts         0.124008  0.124008  0.288074  0.310966 -0.307738  0.187872
#
#                 ThrB       Pts
# Age         0.014145  0.049275
# Apps        0.046135  0.346365
# Mins       -0.070739  0.308440
# Goals       0.567614  0.242959
# Assists     0.425535  0.485206
# Yellow      0.270993  0.110472
# Red        -0.052683 -0.063370
# SpG         0.511013  0.345031
# PS          0.097434  0.310966
# Aerialswon -0.130626 -0.022031
# MotM        0.502871  0.231030
# Rating      0.328914  0.619752
# Tackles    -0.181730  0.021374
# Inter       0.124388  0.001500
# Fouls       0.072796 -0.118999
# Offsides         NaN       NaN
# Clear      -0.120862 -0.226180
# Drb_def    -0.221122 -0.204782
# Blocks     -0.291267 -0.455220
# OwnG        0.174968  0.006884
# Drb_off     0.440282  0.227352
# Fouled      0.223145  0.363109
# Off         0.446209  0.099427
# Disp        0.221542  0.124008
# UnsTch      0.221542  0.124008
# AvgP       -0.133880  0.288074
# PSp         0.097434  0.310966
# Crosses    -0.034526 -0.307738
# LonB        0.496575  0.187872
# ThrB        1.000000  0.341252
# Pts         0.341252  1.000000
#
# [31 rows x 31 columns]

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(FW_corr_matrix)
plt.title('FW values Corr')
plt.show()

# %%
# 결과가 nan인 변수 제거

FW_df.drop('Offsides', axis=1, inplace=True)
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/3906869653.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FW_df.drop('Offsides', axis=1, inplace=True)

# %%
FW_df.columns
# Out:
# Index(['Name', 'Team', 'Age', 'Position', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yellow', 'Red', 'SpG', 'PS', 'Aerialswon', 'MotM', 'Rating', 'Tackles',
#        'Inter', 'Fouls', 'Clear', 'Drb_def', 'Blocks', 'OwnG', 'Drb_off',
#        'Fouled', 'Off', 'Disp', 'UnsTch', 'AvgP', 'PSp', 'Crosses', 'LonB',
#        'ThrB', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

# Drb_def     0.305420  0.305420  0.082636 -0.000500  0.203861  0.105355
# Blocks     -0.136163 -0.136163  0.059606 -0.118297 -0.050145 -0.237510
# OwnG       -0.130505 -0.130505 -0.017474  0.021025 -0.195140  0.218542
# Drb_off     0.747182  0.747182 -0.042611  0.062462  0.541887  0.245709
# Fouled      0.632993  0.632993  0.100946  0.114156  0.322000  0.268281
# Off         0.521398  0.521398 -0.001495  0.065226  0.189794  0.106895
# Disp        1.000000  1.000000  0.022033  0.088469  0.474688  0.241893
# UnsTch      1.000000  1.000000  0.022033  0.088469  0.474688  0.241893
# AvgP        0.022033  0.022033  1.000000  0.629490 -0.087515 -0.072689
# PSp         0.088469  0.088469  0.629490  1.000000 -0.013000  0.257215
# Crosses     0.474688  0.474688 -0.087515 -0.013000  1.000000 -0.023128
# LonB        0.241893  0.241893 -0.072689  0.257215 -0.023128  1.000000
# ThrB        0.221542  0.221542 -0.133880  0.097434 -0.034526  0.496575
# Pts         0.124008  0.124008  0.288074  0.310966 -0.307738  0.187872
#
#                 ThrB       Pts
# Age         0.014145  0.049275
# Apps        0.046135  0.346365
# Mins       -0.070739  0.308440
# Goals       0.567614  0.242959
# Assists     0.425535  0.485206
# Yellow      0.270993  0.110472
# Red        -0.052683 -0.063370
# SpG         0.511013  0.345031
# PS          0.097434  0.310966
# Aerialswon -0.130626 -0.022031
# MotM        0.502871  0.231030
# Rating      0.328914  0.619752
# Tackles    -0.181730  0.021374
# Inter       0.124388  0.001500
# Fouls       0.072796 -0.118999
# Clear      -0.120862 -0.226180
# Drb_def    -0.221122 -0.204782
# Blocks     -0.291267 -0.455220
# OwnG        0.174968  0.006884
# Drb_off     0.440282  0.227352
# Fouled      0.223145  0.363109
# Off         0.446209  0.099427
# Disp        0.221542  0.124008
# UnsTch      0.221542  0.124008
# AvgP       -0.133880  0.288074
# PSp         0.097434  0.310966
# Crosses    -0.034526 -0.307738
# LonB        0.496575  0.187872
# ThrB        1.000000  0.341252
# Pts         0.341252  1.000000
#
# [30 rows x 30 columns]

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(FW_corr_matrix)
plt.title('FW values Corr')
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

FW_corr_matrix_Pts = FW_corr_matrix[['Pts']]
FW_corr_matrix_Pts
# Out:
#                  Pts
# Age         0.049275
# Apps        0.346365
# Mins        0.308440
# Goals       0.242959
# Assists     0.485206
# Yellow      0.110472
# Red        -0.063370
# SpG         0.345031
# PS          0.310966
# Aerialswon -0.022031
# MotM        0.231030
# Rating      0.619752
# Tackles     0.021374
# Inter       0.001500
# Fouls      -0.118999
# Clear      -0.226180
# Drb_def    -0.204782
# Blocks     -0.455220
# OwnG        0.006884
# Drb_off     0.227352
# Fouled      0.363109
# Off         0.099427
# Disp        0.124008
# UnsTch      0.124008
# AvgP        0.288074
# PSp         0.310966
# Crosses    -0.307738
# LonB        0.187872
# ThrB        0.341252
# Pts         1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화

FW_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(FW_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/2438261396.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FW_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %% [markdown]
# # AM 포지션

# %%
AM_df.shape
# Out:
# (264, 34)

# %%
AM_df.columns
# Out:
# Index(['Name', 'Team', 'Age', 'Position', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yellow', 'Red', 'SpG', 'PS', 'Aerialswon', 'MotM', 'Rating', 'Tackles',
#        'Inter', 'Fouls', 'Offsides', 'Clear', 'Drb_def', 'Blocks', 'OwnG',
#        'Drb_off', 'Fouled', 'Off', 'Disp', 'UnsTch', 'AvgP', 'PSp', 'Crosses',
#        'LonB', 'ThrB', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

AM_numeric_df = AM_df.select_dtypes(['int64', 'float64'])

# %%
AM_corr_matrix = AM_numeric_df.corr()
AM_corr_matrix
# Out:
#                  Age      Apps      Mins     Goals   Assists    Yellow  \
# Age         1.000000 -0.087711  0.029901 -0.035561 -0.086304 -0.044699
# Apps       -0.087711  1.000000  0.228081  0.710369  0.404528  0.273830
# Mins        0.029901  0.228081  1.000000  0.221423  0.166615  0.131176
# Goals      -0.035561  0.710369  0.221423  1.000000  0.408420  0.044324
# Assists    -0.086304  0.404528  0.166615  0.408420  1.000000  0.287479
# Yellow     -0.044699  0.273830  0.131176  0.044324  0.287479  1.000000
# Red        -0.003007 -0.049977 -0.050352  0.000961  0.005426  0.084451
# SpG        -0.046987  0.578061  0.231653  0.779913  0.291458  0.149441
# PS         -0.057658  0.035720  0.196035  0.139311  0.068342 -0.024338
# Aerialswon -0.015620  0.282696  0.095295  0.187083 -0.034459  0.299207
# MotM       -0.120710  0.582158  0.198282  0.747629  0.548039  0.108677
# Rating     -0.066455  0.251706  0.555834  0.422552  0.206907  0.013680
# Tackles    -0.053058  0.077952  0.083519 -0.153748  0.328928  0.534136
# Inter      -0.056033  0.100436  0.056742 -0.178591  0.187102  0.527873
# Fouls      -0.055439  0.237598  0.085069  0.031448  0.009066  0.580556
# Offsides   -0.031103  0.102595  0.067633 -0.015074  0.044987  0.157846
# Clear       0.032661  0.284194  0.088780  0.007651 -0.065235  0.310470
# Drb_def    -0.133405  0.067017  0.044078 -0.029405  0.359091  0.218125
# Blocks     -0.029756  0.156731  0.082375 -0.006480  0.123446  0.216584
# OwnG       -0.059872  0.115139  0.054179 -0.045165  0.035180  0.156660
# Drb_off    -0.134846  0.293470  0.128110  0.252389  0.435350  0.174202
# Fouled     -0.048248 -0.096911  0.049816 -0.074551  0.117812  0.265010
# Off         0.059510  0.265906  0.117889  0.375459  0.050275  0.271896
# Disp       -0.092566  0.170064  0.093354  0.195272  0.129547  0.138531
# UnsTch     -0.092566  0.170064  0.093354  0.195272  0.129547  0.138531
# Off         0.048471  0.168554
# Disp        0.237335  0.135666
# UnsTch      0.237335  0.135666
# AvgP        0.107737  0.226561
# PSp         0.150841  0.331670
# Crosses     0.249865  0.081042
# LonB        0.104105 -0.094453
# ThrB        1.000000  0.191811
# Pts         0.191811  1.000000
#
# [31 rows x 31 columns]

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(AM_corr_matrix)
plt.title('AM values Corr')
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

AM_corr_matrix_Pts = AM_corr_matrix[['Pts']]
AM_corr_matrix_Pts
# Out:
#                  Pts
# Age         0.015718
# Apps        0.166151
# Mins        0.053108
# Goals       0.415839
# Assists     0.149641
# Yellow     -0.164875
# Red        -0.105905
# SpG         0.315903
# PS          0.331670
# Aerialswon -0.036822
# MotM        0.328410
# Rating      0.476810
# Tackles    -0.260565
# Inter      -0.259601
# Fouls      -0.116923
# Offsides   -0.045452
# Clear      -0.226257
# Drb_def    -0.125196
# Blocks     -0.250157
# OwnG       -0.110444
# Drb_off     0.181408
# Fouled     -0.112222
# Off         0.168554
# Disp        0.135666
# UnsTch      0.135666
# AvgP        0.226561
# PSp         0.331670
# Crosses     0.081042
# LonB       -0.094453
# ThrB        0.191811
# Pts         1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화
# 전체적으로 Pts와의 상관관계가 조금 낮은 상태..

AM_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(AM_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/478085803.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AM_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %% [markdown]
# # M포지션 데이터

# %%
M_df.shape
# Out:
# (325, 34)

# %%
M_df.columns
# Out:
# Index(['Name', 'Team', 'Age', 'Position', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yellow', 'Red', 'SpG', 'PS', 'Aerialswon', 'MotM', 'Rating', 'Tackles',
#        'Inter', 'Fouls', 'Offsides', 'Clear', 'Drb_def', 'Blocks', 'OwnG',
#        'Drb_off', 'Fouled', 'Off', 'Disp', 'UnsTch', 'AvgP', 'PSp', 'Crosses',
#        'LonB', 'ThrB', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

M_numeric_df = M_df.select_dtypes(['int64', 'float64'])

# %%
M_corr_matrix = M_numeric_df.corr()
M_corr_matrix
# Out:
#                  Age      Apps      Mins     Goals   Assists    Yellow  \
# Age         1.000000  0.046205  0.112620 -0.046903  0.013035  0.029104
# Apps        0.046205  1.000000  0.295192  0.381729  0.514800  0.193160
# Mins        0.112620  0.295192  1.000000  0.142801  0.157754  0.033983
# Goals      -0.046903  0.381729  0.142801  1.000000  0.450588 -0.190326
# Assists     0.013035  0.514800  0.157754  0.450588  1.000000 -0.002973
# Yellow      0.029104  0.193160  0.033983 -0.190326 -0.002973  1.000000
# Red        -0.056635 -0.123450  0.032103  0.008272 -0.064146 -0.088325
# Off         0.354341  0.354341 -0.022306 -0.015336  0.076014 -0.308344
# Disp        1.000000  1.000000  0.045738  0.035501  0.204274 -0.046938
# UnsTch      1.000000  1.000000  0.045738  0.035501  0.204274 -0.046938
# AvgP        0.045738  0.045738  1.000000  0.660566  0.008907  0.185110
# PSp         0.035501  0.035501  0.660566  1.000000  0.003914  0.032953
# Crosses     0.204274  0.204274  0.008907  0.003914  1.000000  0.360166
# LonB       -0.046938 -0.046938  0.185110  0.032953  0.360166  1.000000
# ThrB        0.307193  0.307193  0.042287 -0.010317  0.381820  0.304033
# Pts         0.034688  0.034688  0.193007  0.339040  0.150088  0.052251
#
#                 ThrB       Pts
# Age        -0.032234 -0.067049
# Apps        0.203592  0.007557
# Mins        0.092215 -0.070917
# Goals       0.258349  0.277623
# Assists     0.622865  0.298560
# Yellow      0.075159 -0.096398
# Red        -0.130548  0.003004
# SpG         0.453188  0.201204
# PS         -0.010317  0.339040
# Aerialswon -0.085046 -0.225753
# MotM        0.479375  0.263520
# Rating      0.146349  0.460744
# Tackles     0.049750 -0.060148
# Inter      -0.119761 -0.211759
# Fouls       0.081126 -0.099102
# Offsides   -0.129548 -0.194341
# Clear      -0.136787 -0.246831
# Drb_def     0.146932 -0.048572
# Blocks      0.085708 -0.184709
# OwnG       -0.087628  0.145644
# Drb_off     0.248717  0.201891
# Fouled      0.281655 -0.089658
# Off         0.310368  0.081270
# Disp        0.307193  0.034688
# UnsTch      0.307193  0.034688
# AvgP        0.042287  0.193007
# PSp        -0.010317  0.339040
# Crosses     0.381820  0.150088
# LonB        0.304033  0.052251
# ThrB        1.000000  0.091725
# Pts         0.091725  1.000000
#
# [31 rows x 31 columns]

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(M_corr_matrix)
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

M_corr_matrix_Pts = M_corr_matrix[['Pts']]
M_corr_matrix_Pts
# Out:
#                  Pts
# Age        -0.067049
# Apps        0.007557
# Mins       -0.070917
# Goals       0.277623
# Assists     0.298560
# Yellow     -0.096398
# Red         0.003004
# SpG         0.201204
# PS          0.339040
# Aerialswon -0.225753
# MotM        0.263520
# Rating      0.460744
# Tackles    -0.060148
# Inter      -0.211759
# Fouls      -0.099102
# Offsides   -0.194341
# Clear      -0.246831
# Drb_def    -0.048572
# Blocks     -0.184709
# OwnG        0.145644
# Drb_off     0.201891
# Fouled     -0.089658
# Off         0.081270
# Disp        0.034688
# UnsTch      0.034688
# AvgP        0.193007
# PSp         0.339040
# Crosses     0.150088
# LonB        0.052251
# ThrB        0.091725
# Pts         1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화
# 전체적으로 Pts와의 상관관계가 조금 낮은 상태..

M_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(M_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_61233/1254075917.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   M_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
