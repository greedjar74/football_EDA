# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
player_stats_df = pd.read_csv('./data/2022-2023_EPL_Player_Statistics.csv')
player_stats_df
# Out:
#      Unnamed: 0  Rank                  Name               Team  Age  \
# 0             0     1       Kevin De Bruyne           Man City   32
# 1             1     2        Erling Haaland           Man City   23
# 2             2     3            Harry Kane          Tottenham   30
# 3             3     4       Bruno Fernandes            Man Utd   29
# 4             4     5         Gabriel Jesus            Arsenal   27
# ..          ...   ...                   ...                ...  ...
# 303         303   304          Dennis Praet          Leicester   29
# 304         304   305  Jean-Philippe Mateta     Crystal Palace   26
# 305         305   306          Flynn Downes           West Ham   25
# 306         306   307            Tom Davies            Everton   25
# 307         307   308          Sam Surridge  Nottingham Forest   25
#
#        Position   Apps  Mins Goals Assists Yellow Red  SpG    PS Aerialswon  \
# ...

# %%
player_stats_df = player_stats_df.drop('Unnamed: 0', axis=1)
player_stats_df
# Out:
#      Rank                  Name               Team  Age    Position   Apps  \
# 0       1       Kevin De Bruyne           Man City   32   M(CLR),FW  28(4)
# 1       2        Erling Haaland           Man City   23          FW  33(2)
# 2       3            Harry Kane          Tottenham   30    AM(C),FW     38
# 3       4       Bruno Fernandes            Man Utd   29      M(CLR)     37
# 4       5         Gabriel Jesus            Arsenal   27   AM(LR),FW  24(2)
# ..    ...                   ...                ...  ...         ...    ...
# 303   304          Dennis Praet          Leicester   29      AM(CR)  6(16)
# 304   305  Jean-Philippe Mateta     Crystal Palace   26          FW  6(23)
# 305   306          Flynn Downes           West Ham   25        M(C)  7(14)
# 306   307            Tom Davies            Everton   25        M(C)  4(15)
# 307   308          Sam Surridge  Nottingham Forest   25          FW  1(19)
#
# ...

# %%
player_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        308 non-null    int64
#  1   Name        308 non-null    object
#  2   Team        308 non-null    object
#  3   Age         308 non-null    int64
#  4   Position    308 non-null    object
#  5   Apps        308 non-null    object
#  6   Mins        308 non-null    int64
#  7   Goals       308 non-null    object
#  8   Assists     308 non-null    object
#  9   Yellow      308 non-null    object
#  10  Red         308 non-null    object
#  11  SpG         308 non-null    object
#  12  PS          308 non-null    float64
#  13  Aerialswon  308 non-null    object
#  14  MotM        308 non-null    object
#  15  Rating      308 non-null    float64
# dtypes: float64(2), int64(3), object(11)
# memory usage: 38.6+ KB

# %%
# '-'로 된 결측치를 np.nan으로 바꿔준다.
player_stats_df = player_stats_df.replace('-', np.nan)
player_stats_df
# Out:
#      Rank                  Name               Team  Age    Position   Apps  \
# 0       1       Kevin De Bruyne           Man City   32   M(CLR),FW  28(4)
# 1       2        Erling Haaland           Man City   23          FW  33(2)
# 2       3            Harry Kane          Tottenham   30    AM(C),FW     38
# 3       4       Bruno Fernandes            Man Utd   29      M(CLR)     37
# 4       5         Gabriel Jesus            Arsenal   27   AM(LR),FW  24(2)
# ..    ...                   ...                ...  ...         ...    ...
# 303   304          Dennis Praet          Leicester   29      AM(CR)  6(16)
# 304   305  Jean-Philippe Mateta     Crystal Palace   26          FW  6(23)
# 305   306          Flynn Downes           West Ham   25        M(C)  7(14)
# 306   307            Tom Davies            Everton   25        M(C)  4(15)
# 307   308          Sam Surridge  Nottingham Forest   25          FW  1(19)
#
# ...

# %%
player_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        308 non-null    int64
#  1   Name        308 non-null    object
#  2   Team        308 non-null    object
#  3   Age         308 non-null    int64
#  4   Position    308 non-null    object
#  5   Apps        308 non-null    object
#  6   Mins        308 non-null    int64
#  7   Goals       211 non-null    object
#  8   Assists     211 non-null    object
#  9   Yellow      280 non-null    object
#  10  Red         22 non-null     object
#  11  SpG         286 non-null    object
#  12  PS          308 non-null    float64
#  13  Aerialswon  306 non-null    object
#  14  MotM        151 non-null    object
#  15  Rating      308 non-null    float64
# dtypes: float64(2), int64(3), object(11)
# memory usage: 38.6+ KB

# %%
player_stats_df.isna().sum()
# Out:
# Rank            0
# Name            0
# Team            0
# Age             0
# Position        0
# Apps            0
# Mins            0
# Goals          97
# Assists        97
# Yellow         28
# Red           286
# SpG            22
# PS              0
# Aerialswon      2
# MotM          157
# Rating          0
# dtype: int64

# %%
player_stats_df.replace(np.nan, '0')
# Out:
#      Rank                  Name               Team  Age    Position   Apps  \
# 0       1       Kevin De Bruyne           Man City   32   M(CLR),FW  28(4)
# 1       2        Erling Haaland           Man City   23          FW  33(2)
# 2       3            Harry Kane          Tottenham   30    AM(C),FW     38
# 3       4       Bruno Fernandes            Man Utd   29      M(CLR)     37
# 4       5         Gabriel Jesus            Arsenal   27   AM(LR),FW  24(2)
# ..    ...                   ...                ...  ...         ...    ...
# 303   304          Dennis Praet          Leicester   29      AM(CR)  6(16)
# 304   305  Jean-Philippe Mateta     Crystal Palace   26          FW  6(23)
# 305   306          Flynn Downes           West Ham   25        M(C)  7(14)
# 306   307            Tom Davies            Everton   25        M(C)  4(15)
# 307   308          Sam Surridge  Nottingham Forest   25          FW  1(19)
#
# ...
